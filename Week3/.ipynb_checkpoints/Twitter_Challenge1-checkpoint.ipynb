# %% [markdown]
# # Twitter Challenge 1
#
#
# ## Recall that you were asked to retrieve ~ 10K tweets last week.
#
# ## Do the following:
#
# 1. Use any Python package(s) of your choice
# 2. Perform text pre-processing
# 3. Generate a word cloud
# 4. Post the word cloud (image) as a Tweet (using your own Twitter account).
#
# ### Briefly describe: what is the topic? what is the data period?
# ### Include #is434 #smu #scis hashtags in your tweet.

# %%
import pandas as pd
import plotly.graph_objects as go
from twarc import Twarc2

# %%
df = pd.read_csv('tsla_tweets.csv')
df.head()
# Out:
#    Unnamed: 0                   Datetime      Tweet Id  \
# 0           0  2021-08-30 23:59:56+00:00  1.432490e+18
# 1           1  2021-08-30 23:59:38+00:00  1.432490e+18
# 2           2  2021-08-30 23:59:34+00:00  1.432490e+18
# 3           3  2021-08-30 23:59:29+00:00  1.432490e+18
# 4           4  2021-08-30 23:59:22+00:00  1.432490e+18
#
#                                                 Text         Username
# 0  $ZM break of $300.00 $275.00 coming fast\n\nht...     techoptrader
# 1  @TreMoneyball @BlackBoxStocks An example today...  SheriAnvarzadeh
# 2  This harmonic. 😂 from $650 to $780 \nRemember ...  eddie_2thepoint
# 3  @squawksquare Yes please and thank $TSLA  very...    Donna28421555
# 4     @garyblack00 What’s your PT for $TSLA by 2025?     oseiserebour

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10001 non-null  int64
#  1   Datetime    10001 non-null  object
#  2   Tweet Id    10001 non-null  float64
#  3   Text        10001 non-null  object
#  4   Username    10001 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 390.8+ KB

# %%
tweet_text_list = df['Text'].tolist()

tweet_text_list
# Out:
# ['$ZM break of $300.00 $275.00 coming fast\n\nhttps://t.co/rFu3nXh5YL\n\n$SPX $SPY $DIA $IWM $GLD $SLV $TSLA \n #optionstrading #trading #trader #options #stocks \n#daytrading #investor #swingtrading\n\n@TrendSpider https://t.co/gVwlBqm1XR',
#  '@TreMoneyball @BlackBoxStocks An example today was $TSLA. it had the inside bar on the day and TSLA doesn’t have many of those. When alert hit a few times today I was comfortable to take the trade. Hope it makes sense.',
#  'This harmonic. 😂 from $650 to $780 \nRemember this tweet $tsla \nCalled it 8/17',
#  '@squawksquare Yes please and thank $TSLA  very much!',
#  '@garyblack00 What’s your PT for $TSLA by 2025?',
#  'Elon liked this tweet.\n\n👇\n\n$TSLA https://t.co/IeASTz4i7D',
#  'Equity Idea Highlights Today:\n\n$GME Long 7pts\n$SPRT Long 5pts\n$AFRM Long 5pts Total\n$TSLA Long 4pts+\n$NVAX Long 2pts\n$BFV Long 1.5pts+\n\nLive Stream, 24/7 Chat &amp; Support\nStocks &amp; Options\nhttps://t.co/6gdeoRgs5p\nPromos\n50% off weekly: AG50\n25% off monthly day trading: AG25 https://t.co/buhfMpVzyM',
#  '@garyblack00 Tsla back to $900',
#  "@Trendspider_J Let's hope this wasn't just a tease from TSLA!",
#  'First recap in two weeks.  It’s good to be back $spy $qqq $aapl $tsla $amd $pltr. \n\nhttps://t.co/8q1AviCkid',
#  'I shared this trigger list last week.\nTook patience but we got it to the T today on $TSLA 713 trigger to bring 731. \U0001f90c🏼✅ https://t.co/K9bI7ZGYra',
#  'So part shortage done?\n\nNice.\n\n$TSLA https://t.co/GgUl6GSGKp',
#  '@elonmusk $TSLA to the moon that’s all the DD I needed 💥🍻',
#  '@garyblack00 @daniel_toloko Yeah!  The longer the consolidation, the stronger the breakout (to the upside for TSLA).',
#  'The Musk Variant  $TSLA https://t.co/dBhnHODDAS',
#  '@hikingskiing $abml with @Tesla gun Ryan Melsert now the CEO and their first of a kind closed loop lithium battery recycling plant about to be built $abml $tsla',
#  '@hikingskiing Selling TSLA puts',
#  '@RichShippy @DelpuYannick $BNGO the $TSLA of medical field',
#  '@ParrotStock I’m watching \n\n$ZM\n$DOCU\n$MQ\n$TSLA\n$MRNA\n$ASML',
#  'WHAT A DAY TO TRADE\nSMALL CAP SHORTY\nTODAY WAS #AWESOME ITS MONDAY &amp; WE WERE GIVEN A LOT OF OPPORTUNITIES\nAFTER DOING THE RESEARCH ON ABOUT 60+ STOCKS THIS MORNING\nHERE ARE JUST FEW WE DID LIVE IN #ACT\nAj\n\n$TSLA\n$CRWD\n$ATER\n$BBIG\n$ROOT\n$MRNA\n$BNTX\n$MQ\n\nhttps://t.co/yGj5JlomLc https://t.co/zmEjMhAnbU',
#  '架空のポートフォリオ\n前日比\u3000+1.08%\u3000毎日エブリデイ(*´︶`*)♡・・・💕\n\n$TSLA +2.67%  〇・・・😼\n$RPRX -0.48%  △・・・🐱\n$BLDE -3.14%  ✖・・・🙀\n$APPS -2.59%  ✖・・・😿 https://t.co/qF2i9wJp00',
#  '$GPS: 10B Cap with https://t.co/OG5Qr4TFhZ\n\n$PTRA  $ARVL $WIX $SKLZ $OPEN $HOOD $LEV $CHPT $IDEX $GRPN $Z $GGPI $WISH $SOFI $LCID $TSLA $TBLA $MVST $BARK $F $FSR $AMC $SPY $ETH $NIO $BABA $BTC $CLOV $AAPL $PLTR $GME $QS $TSLA $BA $SPCE  $Doge $Plug $FB $NVDA $LGF.A',
#  '@stevenmarkryan TSLA to the moon.  I am waiting days and nights for it.  Lol.',
#  'Personally like $TSLA, $SQ, $MSFT, and $AMZN in the morning tomorrow but we will see what the market has prepared for us !!',
#  '@elonmusk $tsla to 1k',
#  'How about banning selling non existent product like say FSD? $tsla $tslaq #tesla https://t.co/eshxjfUKAT',
#  '$TSLA\nいい感じだと思います\n今から再度入るか？と言われると悩みます https://t.co/FZ0EUqEeJ7',
#  'صفقتين ناجحة 💚\n في سهم $BBIG على قناة التيليقرام:\nhttps://t.co/8PdeFnKWr4\n\n—-\n$KPLT $ARVL $WIX $SKLZ $OPEN $HOOD $LEV $IDEX $GRPN $Z $GGPI $WISH $SOFI $LCID $TSLA $TBLA $MVST $BARK $F $FSR $AMC $SPY $ETH $NIO $BABA $BTC $CLOV $AAPL $PLTR $GME $QS $TSLA $BA $SPCE  $Doge $Plug $FB https://t.co/jJmH0Y5tCD',
#  '@elonmusk $TSLA 750c',
#  '@CatzNews $TSLA closed highest since Apr 26 2021 at 730.91\n687👉730\n\n#Technical looks good for near term\n\nSince Aug 1, it gave chance to enter at 665 levels https://t.co/SBwjraL4zC',
#  "$AAPL bullseye works extremely well on trending days! This and another buy call trade idea from August 27th are up like 300% on average! 😍\n\nObviously I'm cherry picking here, but even if I don't, the returns over the last few days are crazy. \n\n$FB\n$IWM\n$MSFT\n$TSLA https://t.co/dNoEgQp6SK https://t.co/hifLxe97iz",
#  '@FradeDuarte 1) $TSLA (Add)\n2) $SE (Add)\n3) $NVDA (New)',
#  '&lt;오늘아침 (1)&gt; \n\n좋은 아침입니다. \n\n간밤에 마켓은 9월 고용보고서를 기다리며 혼조세(다우하락, S&amp;P, 나스닥 신고가)로 마감을 했습니다. \n\n그리고 $TSLA 에 대한 저의 예상이 우연히도 딱 맞았네요(자랑). #테슬라 는 2.67% 상승한 730.91로 마감을 했습니다. (계속)\n\n#경제적자유 https://t.co/bHxvldgp6B',
#  '@StanphylCap Someone has a short position on Tsla lol',
#  '@ORStatePolice Buy the $TSLA dip',
#  '@SYCbkhCmvGTZ97Y ＄TSLAやっと買値に戻ったから、やれやれ売りしたら…🤣🤣🤣\n\n売ったらアガール発動❤️\nｻﾞｹﾝﾅﾖｻﾞｹﾝﾅﾖ😤\n\nま、損はして無いから良しとします笑笑\n\n利確は正義*\\(^o^)/*',
#  '$TSLA speed https://t.co/lM0Nu8dZxr',
#  '$tslaq $tsla #tesla https://t.co/6fjsSUVked',
#  '[Last 2 Hours]\n\nStocks Trending among Elite #fintwit Traders: \n1. $TSLA 🥇\n2. $BBIG 🥈\n3. $AAPL 🥉\n4. $PYPL\n5. $AMZN\n6. $SQ\n7. $AFRM\n8. $FB\n9. $ZM\n10. $GSAT\n\n#investing #stocks #wallstreetbets\n\nJoin the official Telegram for more frequent updates: \nhttps://t.co/d6SI8SpZyz https://t.co/3PJLnZlw3f',
#  'Our $TSLA #Calloption worked making a move today from previous close of $712 to $730 $SPY \nNext PT @ $750 by Friday ! #DM to join our team today and start making money from your $AAPL #iPhone or #Andriod device from anywhere in the world ! https://t.co/BYPA6H7hUO',
#  '[Last 24 Hours]\n\nStocks Trending among Elite #fintwit Traders: \n1. $BBIG 🥇\n2. $TSLA 🥈\n3. $AAPL 🥉\n4. $AMZN\n5. $SPRT\n6. $AFRM\n7. $ANY\n8. $FB\n9. $KPLT\n10. $AMD\n\n#investing #stocks #wallstreetbets\n\nJoin the official Telegram for more frequent updates: \nhttps://t.co/d6SI8SpZyz https://t.co/cAatLyR8aR',
#  '$TSLA  Real price will come out soon; Follow price targets:..,,..  \n\nhttps://t.co/SUOxzp8XEC',
#  '4 Top Stock Trades for Tuesday: AFRM, FB, ZM, TSLA | https://t.co/QVDitSq43E | #investment #stocks https://t.co/wVTy688bhd',
#  '$PTRA\nBest A.I https://t.co/P6qFTFS0kf\n\n$KPLT $ARVL $WIX $SKLZ $OPEN $HOOD $LEV $CHPT $IDEX $GRPN $Z $GGPI $WISH $SOFI $LCID $TSLA $TBLA $MVST $BARK $F $FSR $AMC $SPY $ETH $NIO $BABA $BTC $CLOV $AAPL $PLTR $GME $QS $TSLA $BA $SPCE  $Doge $Plug $FB $NVDA',
#  '@Trendspider_J GO GO GO tsla, PT 3000',
#  '$TSLA ! https://t.co/cOk2YldvE1',
#  '@TopGunFP here\'s a primer, every stock will be different in terms of price - for ex TSLA every 20 dollar move up or down matters anything below is "noise" - you don\'t use this for option trading just commons and time is a non factor.\n\nhttps://t.co/xO6MjYEO4q',
#  'Keep listening to @CNBC and the rest of the media! "Competition" is coming! $TSLA $GM https://t.co/Mi55mRlC94',
#  '@garyblack00 In my management school academic and friends working in finance sector, understanding $TSLA valuation is a blasphemy. It just violates every rule they have learnt so far I investing and they never accept that they are traditionally bad in identifying innovative companies',
#  'Elon Musk liked a tweet from ⚡️Tesla Owners Online #Tesla $TSLA https://t.co/2IH561Tle2',
#  '@daniel_toloko @garyblack00 deadweight has its intrinsic value. $TSLA can add a lot more load and passengers.\n\n$tslaq soon will meet its deadend.😄',
#  "@garyblack00 Well the shorts had 3 good months to short $TSLA so I think they're good. $TSLA is not moving like it used to. It took $TSLA an entire month of back and forth &amp; dip to alas break $725 again. It's been in a rebuilding channel since Mid-may &amp; finally moving higher.",
#  '@leverageyellow 下げたら買うのみ❤️\nETF買い増しチャーンス⭐️⭐️⭐️\n\n個別株整理したくて＄TSLA売却したら上がってるし🤣🤣🤣ムカつく❤️\n\nま、余力増やしてETF買い増ししてやるぜよ❤️',
#  'TSLAも、なかなかええ形しとるよの https://t.co/qUOfGs23g9',
#  'Electric Vehicle ETF $DRIV holds $QCOM $INTC $AAPL $TSLA and $NIO\n\n$DRIV formed a Wave 1 and 2 from the March 2020 low then went on a Wave 3 rally that ended at 28 before putting in a Wave 4 at the 23.6% retracement\n\nif $DRIV &gt; 24.90 the Wave 5 target is 33.50 and then 38 in 3-6M https://t.co/zclu6D0Plq',
#  '$TSLA Super breakout today\n\nhttps://t.co/se0tIfBG4D',
#  'This is a way Hedge Funds get away with Fraud and the brokers helped them with the easy to Borrow READ what its about.  $SPRT $GME $AMC $GTII $KOSS $PLUG $RIOT $TSLA $BYND $GTII $PTON $FCEL $NWBO $EYES $EKSO $BBIG $ROOT \n\nhttps://t.co/8YrAduV06C',
#  'The faster $TSLA rise, the faster $TSLA rise...\n\nWhen bull getting more and more margins. https://t.co/y4O33xH5KH',
#  '#TerrificTuesday #BMTALERTS 🚨 $TSLA\n\nEntry for *Calls* above $730 which is already valid (Targets: $750, $760, $780 &amp; SL below $724)\n\nEntry for *Puts* below $712 (Targets: $698, $679 &amp; SL above $717)\n\nAfter every target is reached, that becomes your new stop loss https://t.co/rV3uGxYczD',
#  'Stock Picks:  4 Top Stock Trades for Tuesday: AFRM, FB, ZM, TSLA https://t.co/cpf2aNyz79 https://t.co/D3mLZo5jJa',
#  '@snowbullcapital Once $TSLA  establish a plant in #TeslaIndia  exports will be from Giga Shanghai and Giga India for Asian, Middle East and Australia market This picture changes! You will see less exports from China.',
#  '全面高の中AAPLもATH\nGOOGやMSFTへの遅れを取り戻してぐいぐいと言って欲しいところよ\n\nあと今保有しているTSLAとUも堅調で素晴らしい\n\n惜しむらくはジャクソンホール前にポジションを縮小したことよのw\nまぁ、致し方なし https://t.co/6nJMFr5mrf',
#  'Learn more at \nhttps://t.co/XcdZG7DRDi\n\n$STORY $GNID #BICB $CGNH $DYNT $ARYC $SNDD #PCTL $OZSC $CTYX $LLBO $RSCF $DIS $BBY $BFT #EMED .. $TSLA $SBE $SPY $QQQ $PLTR $PSTH $SBE $JMIA $WKHS https://t.co/0Yl40WBETv',
#  'Watch "The Tesla Model S Plaid Is the World’s Fastest (and Coolest) Sedan" on YouTube - https://t.co/HKhHejcdiB $TSLA',
#  'おはようございます。\n\n昨夜の米国市場では、とにかく大型ハイテクが強かったみたいですね。こういうとき、レバナスや $QQQ が羨ましいです。\n\n$UBER がギグワーカーへの福利厚生を発表したとかで、 -2.7% 逆に $TSLA はインド進出に関するニュースで +2.67% でした。',
#  '$AAPL $TSLA $NVDA $SQ all incredibly bullish darkpools. Unreal @unusual_whales @SharkofTraders',
#  'DAY 30 &amp; DAY 31 ---&gt;$100K\n\n+$6.4K profits last Friday\n+$5.7K profits today\n\n+$12K in just a matter of 2 days\n\n$MQ short, big money\n$ASTR short\n$AFRM short\n\nAlerts, Entries &amp; Exits all inside discord. \nJoin Us\n👇\nhttps://t.co/U3mb9Acdcr\n\n$SPY $NVDA $AAPL $TSLA $MRNA $AMC $GME https://t.co/TbfdbQbg4X',
#  '$TSLA multiple bullish price obj 790 and 980 - this will be negated if stock prints 645. https://t.co/XxbR1Ywpsg',
#  "Most optimistic #StocksInNews from this weekend's news coverage:\n\n1. $AMD Advanced Micro Devices🥇\n2. $LMT Lockheed Martin🥈\n3. $MSFT Microsoft🥉\n4. $TSLA Tesla\n5. $IBM IBM\n6. $GOOG Google\n7. $DOGE Dogecoin\n8. $QCOM Qualcomm\n9. $BTC Bitcoin\n10. $T AT&amp;T\n\nℹ️ https://t.co/K2XcJLFsdM https://t.co/0PHjvbQ2Ks",
#  '$TSLA man do I love this stock. Weekly chart saying we keep on rolling. This is just the beginning. Personally been holding since mid $650s and it doesn’t disappoint. MACD positive ready for flight ✈️ https://t.co/CiTt2AqZj5',
#  '$TSLA was a good play today I misses as well.',
#  '#GM Car of the Year, Motor trend of the year  and $TSLA Killer ! Lol Competition my ….  🤣 https://t.co/jtoT8uKnMl',
#  '@doc_tradez Are you still short TSLA or holding Puts?',
#  '🥴 Seems like a big problem to me 🥴 $GM is better stop dicking around, give back money to owners and tell them to back a $TSLA\n\nhttps://t.co/wlWD6hlFke',
#  '@WOLF_Financial $TSLA just the fact that media and govt. is trying its hard to crush it! Very Bullish Sign!...Others: $PLTR $SOFI',
#  'Weekly breakouts can be very explosive just sayin $tsla https://t.co/pgQzmpZ9PR',
#  'The corkscrew of life runs on AI $tsla and #crypto https://t.co/cE6O0mmmOD',
#  '@TeslaAndBitcoin I cut loss already n put the $$ into Tsla right away. Seems can recover in days 🍷',
#  '@garyblack00 You future earnings are nonsense and a PE of 72 isn’t cheap. $tm current PE 9…. You embarrass yourself $tsla $tslaq #tesla',
#  '前日比(率) -$378(-0.2%)\n含み損益合計(率) +$36943(+36%)\n合計額 $138891\n\n年確定損益 +$12157\n\n含み損益(率)\n$SPYD 2200株 +$30360(+52%)\n$TSLA 11株 +$389(+5%)\n$UBER 50株 +$463(+31%)\n$HDV 334株 +5203(+19%)\n$ABNB 22株 +$425(+14%)\n$QLYD 190株 +$91(+2%)',
#  "$tsla, this hasn't happened in a very long time https://t.co/SuerPZDSME",
#  '$MRNA w/ Bearish Pennant as mentioned Friday..https://t.co/VyUY4pdbys\n\n$SPY $AMZN $AAPL $BA $NFLX\n$TSLA $AMD $ROKU $NVDA $FB\n$TWLO $PYPL $DOCU $CRWD $ETSY $SQ $MSFT $BABA $DKNG $BBIG $SPRT $CORE $PLNT $AMX',
#  '@surayaror #TSLA!',
#  '【2021/08/30 Break-Out Resistance Level Daily(1/4)】\n2021/08/30 上値抵抗線ブレイクアウト銘柄一覧 #米国株 \n$TSLA $SPOT $AVLR $IRDM https://t.co/zO9GpgQDDH',
#  "@squawksquare It was over it 4-5 separate times today. $TSLA going to 2200. hodl. JK I'm a paper account.",
#  "Ross Gerber + Gary Black + Cathie Wood.\nLike 3 PPP's in a pod.\n#Tesla $TSLA $TSLAQ https://t.co/kEV6bDv218",
#  '@hikingskiing $NVNXF\n$EMHLF\n$TSLA\n\nAs always, DYOR..!!',
#  '@hikingskiing $tsla\n$btc\n$tqqq\n$sq\n$arkk (maybe)\n$msft maybe (unpopular opinion)',
#  '@kinnotamagoblog 名前までは思い出せなかったのでひとまとめにしてしまいました😂笑',
#  'Tuesday Watchlist Pt.2\n\n1) $TSLA Strong breakout/close above resistance,next targets 760/780 💰\n2) $NINE 2.4 breakout 📈\n3) $KALA 3.3 support, breakout over 3.6 🍋 \n4) $ENSV Squeeze over 1.26 🔥\n5) $GME Flagging on daily, 227 break to test 300’s 🚀\n\n🚨Let’s bank big this week 🔥 https://t.co/C0ZzgGRfEt',
#  '⭐️ Freedom Stocks Watchlist For Tomorrow ⭐️\n \n$TSLA\n$ENPH\n$RUN\n$CHPT\n$OEG',
#  '@bevedoni Me as well. I guess most of us $TSLA investors are stupid. Until we are not. 🎊',
#  'But I don’t need to outsmart this. $APPL, $tsla attempting potential base breakout while $nvda broke out last week. If we don’t see major reversals in those names, the indexes end up being fought higher, and tough to see major downside in that tape outside intitial moves',
#  '8/30\n⤴SPX、グロース、不動産、テック、日本、原油、ドル、AAPL、TSLA、AFRM\n\n⤵️小型、VIX、バリュー、金融、エネルギー、中国、金利、金、ビットコイン、MRNA\n\n📝デルタ株→バリュー売り。金融引き締め慎重→グロース買い。今後の相場は経済指標次第か。',
#  '@liquidcactus @TTYNGAI @rbc_trading tsla daily pretty much as you have it https://t.co/fUMTAskDag',
#  '@tsla_Elon ディズニーの悪役🤣🤣🤣\n\nやっぱ笑顔の素敵な女性にはキュンとしますね😆',
#  '@garyblack00 I guess most of HF &amp; Analysts do not know how to value a growth cokpany specifically such as $TSLA. Its always fun to see you "breaking the ice" for them! Thank for the usual insights!',
#  'Lol 😂 A dancer in Lycra? Please just stop 🛑 $tsla $tslaq #tesla https://t.co/ANLrPRZjJb',
#  'This one line explanation of #tsla valuation 😊 https://t.co/VVsXc9TijY',
#  'Anyone gonna go out on a limb and say $tsla $800 this week? That’s a 10% move over the next 4 days.',
#  'السهم اخترق ٧٢٦.٩٤ \n\nوأغلق أعلاها .. 🤓😊\n\nالأعلى ٧٣١  ..  إلى الأهداف بإذن الله .. بالتوفيق \n\n#تاسي \n#تسلا\n#تداول_السعودية \n#اسهم \n#الأسهم_الأمريكية \n#الاسهم_السعودية \n#اوبشن \n#النفط \n#التكنولوجيا \n#tasi \n#TSLA \n#AAPL \n#dowjones \n#options \n#Stoke',
#  '* Sold more $TSLA shares today for $725',
#  '@garyblack00 Simple….human emotion / peer pressure, fomo.\nThat will make people dream up scenarios of unreal growth and earnings. \nReality is tsla is an ugly bubble.\nLike in any bubbles, when it burst it will be so stupidly clear why #bubbles',
#  '*Grain of salt* but this reddit poster says their Bolt went up in flames at 2am while in a parking lot, not plugged in, and turned "off" whatever that means to a Bolt. $TSLA $gm\n\nhttps://t.co/h2XIWnVoV6',
#  '@WholeMarsBlog i remember Greg. he panic sold his $TSLA way back. he blocked me a while ago for calling out his BS on Tesla. 😂 i didn’t know he already stooped to this level of idiocy 🤣',
#  '8/30 🇺🇸チャートシグナル2⃣\n\n$ON MACDゴールデンクロス\n$NXPI 新高値🚀\n$TSLA MACDゴールデンクロス\n$MQ DI・MACDゴールデンクロス\n$PYPL DIゴールデンクロス\n$UPST 新高値🚀\n$ATLC 新高値🚀\n$CRWD 新高値🚀\n$ZS 新高値🚀\n$S 新高値🚀\n$FTNT 新高値🚀\n$DOCU MACDゴールデンクロス\n$TWLO MACDゴールデン',
#  'Watch list started for tomorrow. Calls or Puts or Either\n\n$TSLA - C\n$SPY- P \n$MSFT - C\n$DIS - C\n$ZM - E but maybe Calls after such a dramatic drop? \n$TWTR - Possible breakout to the up. Watching closely.',
#  'Drove through 4 countries last week, this is what I can tell you about Tesla \n\nThe Netherlands (Amsterdam) has more of them\nFrance (Paris) has less (hardly spotted any)\nBelgium (Brussels) has less as well\nGermany (every city) has more of them.\n\n$TSLA @elonmusk',
#  '2021/08/30 美股 us stock aapl tsla fb\nhttps://t.co/mAPIhFkuTD',
#  "@DCF885 @b_freeze23 @unusual_whales I don't think that was mainly due to Robinhood and similar free to trade brokers though. I think a ton of people genuinely thought TSLA was going to be fail-- which given the history of auto startups, was a good bet. Didn't work out for the shorts though.",
#  "Most mentioned #StocksInNews from this weekend's finance news coverage (8/28-8/29):\n\n1. $AAPL 🥇\n2. $TSLA 🥈\n3. $GOOG 🥉\n4. $AMZN\n5. $MSFT\n6. $FB\n7. $LEO\n8. $NVDA\n9. $BTC\n10. $IBM\nBonus: $COIN 🎖️\n\n📊👇 https://t.co/K2XcJLFsdM https://t.co/HqKTgGrvwd",
#  '@BMT094 Start a M1 finance account- automated investing, daily, weekly, monthly.  Best of all you can borrow 35% LTV on your portfolio value at an incredible 2% interest. Reinvest into TSLA on dips and plateau, along with consistent automated investing. https://t.co/dCClDTl1Fr',
#  'Tesla has 79% of all EV’s registered in the United States.🤯\n\n WHERE IS THE COMPETITION?\n\n#tesla $tsla @elonmusk \n\nThanks to @NYKChannel https://t.co/adBeDWnhYO',
#  '$GTII $AMC $GME $SPRT $XXI $ADIL $FCEL $PLUG $MARA $KOSS $EYES $EKSO $BBIG $ROOT $BB $KODK $PTON $TSLA $NWBO $CVM $VERI $ANY $NKLA $NNOX $DPW \n\na good quick read about the people who we pay to Protect us and their thoughts \n\nhttps://t.co/qjKupEKmuJ',
#  '$AUPH $AUP  fair value $63.01 USD after getting phase 3 FDA approval https://t.co/C9jICZ8Cn5\n\n$SPY $QQQ $IWM $VIX $FB $AAPL $AMZN $GOOG $MSFT $TSLA $NIO $DKNG $PENN $MARA $RIOT $BABA $SPCE $CGC $TLRY $ACB $APHA $GME $PLTR $ZM $BB $MMED $AMD $INTC $CCIV',
#  '$LYFT not Everything is green for me but I still like the https://t.co/XcdZG7Vt1S\n\n$GL $AMD $SPY $INTC $BABA $TSLA $LOW $FB $SQ $QQQ $FSLY $ZM  $BA $JNJ $NIO $TWTR $MSFT $PYPL $QS $SPCE $ATVI $TMUS $BAC $PINS $CGC $TWLO $SNAP $F $GE $GM',
#  '@kiantrades #AAPL #TSLA #ROOT #BBIG',
#  'No wonder Musk went to Texas! $tsla $tslaq #tesla https://t.co/Tfe2H8vRi8',
#  '@hikingskiing Interesting 😊 \n\n37.5% gives you ~ 5 X in 5 years\n\nNothing beats Tesla so it has all 5 top spots\n1.TSLA\n2.TSLA\n3.TSLA\n4.TSLA\n5.TSLA\n6.BTC\n7.PLTR\n8. ARK ETF',
#  '@azul42752837 はい😌\n自分も色々と売却していこうと思ってます！\nて言っても、いろんな銘柄を数株しか持ってないビビリなんですけど笑笑🤣\ntsla嫌らしいですよね😓\nマイナスだから上がるまで持ち続けます📈',
#  'Starting the week strong 🔥\n\n#DayTheCeo #Project3 #Profits #OptionsTrading #Options #Stocks #Investment #Invest $TSLA $AMZN $FB $PYPL https://t.co/WxEYYAK7wB',
#  'Bullish $TSLA https://t.co/foeJmeKMJg',
#  'Cc: @elonmusk $tsla $tslaq https://t.co/mEtNgBIFBz',
#  'Before FSD is available! $tsla $tslaq https://t.co/wCB1XRWSec',
#  'A guy I worked with 15 years ago who now runs a HF DM’d me and asked: “You grew up at Bernstein, you’re so disciplined about valuation, how do you like $TSLA?”\n\nI DM’d him back: “At 74x FY’22 EPS, with 55% Volume &amp; EPS growth between now and 2025, it’s dirt cheap.”\n\nNo response.',
#  '@squawksquare When is $TSLA  getting back to 900 based on your charts and shit',
#  "@DCF885 @b_freeze23 @unusual_whales So you're saying TSLA is overvalued? I would disagree with that, if true.",
#  '$TSLA winnings of initial #BTC investment🙌\n\n$477797786 (35.39 %) (Realized: 272 M)\n(Estimating an average buy price of $35000/BTC with now 38,700 BTC holdings $BTCUSD)\n#Tesla #Bitcoin #crypto',
#  'Trade Ideas📝\n \n$FB 385c over 380\nTargets: 384, 389, 392, 396\nSupport: 372, 367, 361\n \n$TSLA 750c over 735\nTargets: 750, 761, 781\nSupport: 720, 708, 700, 691\n \n$AAPL $TSLA $AMZN $SHOP $NVDA $SPX $GME $AMC $NFLX $GOOGL $NIO $ROKU\n \nMore plans are posted on our private Twitter! https://t.co/iK0YJLoCw5',
#  '$SING On Fire now Solar Stocks will be on fire just getting started. https://t.co/Rp84wLI95y\n\n$SPY $TSLA $AMD $FB $AAPL $QQQ $AMZN $NVDA $BA $BABA $NFLX $TWTR $AAL $NIO $OXY $CCL $USO $DAL $INO $TWLO $UGAZ $DIS $ROKU $VXRT $CODX $DJIA $SPX $TLRY $SQ $MSFT $GLD $BYND $SRNE $SPCE',
#  '@GordonJohnson19 @teslashanghai I’ve got a reasonable doubt. He must have a secret account for $TSLA. Otherwise, he couldn’t have said this because I’m very certain he’s checked out the export as well.',
#  '$PLTR 220株追加しましたが朝起きたら少し下げてました😂気にしない気にしない😇\nPFの割合が大きい $TSLA  $QQQ が頑張ってくれてます😊',
#  '◆じっちゃま Fan Index【8/31】\nPoint: 204.32 (1.77%) ※速報値\n\n・今日の騰落率 (構成銘柄数: 30)\nMarqeta $MQ: 4.61%\nApple $AAPL: 3.04%\nTesla $TSLA: 2.67%\nFacebook $FB: 2.15%\nZoom $ZM: 1.96%\n(1/4) https://t.co/gdRobjz6lP',
#  'Highest $TSLA close in the last 126 days … https://t.co/e6POIMm5Ou',
#  '$TSLA 720C trigger ✅\n$AAL 20P trigger ✅\n$PINS 56P trigger ✅\n$WFC 49P trigger ✅ https://t.co/HzmMZ2Clw5',
#  '@SYCbkhCmvGTZ97Y うんうん❤️\n\n私も昨夜の上げ上げ相場で色々売却しました🤗💕💕💖\n\nその後上げてるのが気に要らないケド🤣🤣🤣\n＄TSLAお前だよ❤️',
#  'I bought these today! \nhttps://t.co/p8QTrRGqom\n$TSLA $LCID $ETH',
#  '@TwinsightPro @EliteOptions2 One of my very first trades was a Brando Tsla call which happened to be my biggest trade to date. His levels and documents provide a very clear picture to his tactics in trading. I have referred multiple friends and never heard one negative thing back.',
#  '@hikingskiing &gt; that but:\n\n$OPEN stock and leaps\n$SQ “” “”\n$TSLA “” “”',
#  '4 Top Stock Trades for Tuesday: AFRM, FB, ZM, TSLA\n\nThe bears were caught offside on Friday, betting that the Fed would say something to derail the rally. The opposite was true, as the S&amp;P 500 surged to new all-time highs. That train continued without stopping on Monday...',
#  "@DCF885 @b_freeze23 @unusual_whales I haven't seen that in TSLA, but okay. I'm not sure how you'd know with certainty what caused a stock price to move, but I guess I'll take your word for it 🙄",
#  '@hikingskiing $tsla',
#  '@EveryElonReply @Blklivesmatter LMFAOOOOO JUST AS $TSLA GOES OVER $700 💀💀💀',
#  'おはようございます！\n昨日はダウ、ラッセル2000はマイナス📉\nナスダック、S&amp;P500はプラス📈10年債利回りはわずかにマイナスでした。\n$AFRM $TSLA $DUOL $SKYT $ZM が大きな上げ、 $DLO $MRNA $BNTX が大きな下げ。\n日経先物はめちゃくちゃわずかにプラス！\n8月ラストの株も楽しみたいと思います。',
#  '$TSLA 734 AH looking solid.',
#  '$TSLA next resistance (targets) 750 and 770.  \n\nMust hold 720 to keep momentum going. Close below 712, upside move stalled.\n\nOther support / resistance levels as marked. https://t.co/08OXswslSB',
#  'Tesla | $TSLA\n\nstrategy for TSLA Tuesday 08/31/2021\n\nLong or short it with BTC on Trade8: https://t.co/qbQ9zkhKZq https://t.co/dPxHyd3st1',
#  'Today’s plays: $AAPL 10SEP21 157.5 C @ $0.50 e/c and $TSLA 10SEP21 745 C @ 7.57',
#  '@TeslaAviation Rixh ass i have about 420 option contracts of TSLA #bullishaf',
#  'October, 2018\n\nElon Musk: "...Tesla will aim to cover all regions of NA (not just big cities) within 3 to 6 months."\n\n$TSLA $TSLAQ\n\nhttps://t.co/TpyZQdH574',
#  '$TSLA （テスラ）も同様。長期目線で他社に比べて「明らかに」競合優位性があると思うしそう思う限り見守る。（持ち続ける、と同義ではない）\n実際のTesla車に乗ってみても、代替がきくようなクルマは他に無いしな、実際。\n逆にいうとTeslaじゃなくても代替できるようになったら俺は$TSLA利確する',
#  'Big day today💵\n\n$AAPL\n$AMZN\n$FB\n$TSLA',
#  '@garyblack00 @daniel_toloko congrats on your portfolio tsla holdings 630 -&gt; 734',
#  "Can't wait for the $TSLA to expedite service center openings stories in 3. . . 2 . . https://t.co/9vhUg1Z1G9 https://t.co/kmGOoRlBrh",
#  '@GerberKawasaki Ross your thoughts on companies that produce cars, but not the power source having to build out the supply chain. Seems like Tesla grew up sourcing their power materials and OEMs have always relied on big oil. Do OEMs have that sort of in house talent to compete w/tsla?',
#  '上海香港欧州↑\n金利続落1.3割れ\nダウ一時高値抜け陰線\nSPナス終値最高値更新継続\n半導体FAANGM↑金融↓\nTSLA↑BA↓\nモデルナ↓\n消費者信頼感指数、中国PMI発表\n週末雇用統計\n中国ゲーム規制報道再び\nEU渡航制限\n【ダウ平均CFD】+18 (+0.05%) 35418 https://t.co/5R1cW1ReM4  https://t.co/fpN1ZpKov0',
#  "#SOWCDailyList Watchlist for tomorrow: 10 LIKES AND 5 RETWEETS, I'LL POST ANOTHER TOMORROW.\n\n$TSLA 750C &gt; 730\n$ROKU 370C &gt; 366.4, 350P &lt; 351.2\n$DIS 185C &gt; 180.6\n$SQ 280C &gt; 272.4",
#  '$TSLA WOW! Look how strong this trend line has held on the weekly since Mar 2020…. #BullishAF #stockstowatch #CallsIncoming #trading https://t.co/YSA43yXOMP',
#  'Great start on this one \U0001f90c🏼 $TSLA https://t.co/SSsBnuBUQ7 https://t.co/MPsubCF9Zv',
#  'watchlist for today: https://t.co/PSLrgNpi1j\n\n | $BBIG | $NVDA | $AAPL | $PFE | $TSLA | $MRVL | $PTON | $SAVA | $GSAT | $ATER | $SPRT | $AFRM | $NNA | and | $SPY',
#  '[Last 2 Hours]\n\nStocks Trending among Elite #fintwit Traders: \n1. $AAPL 🥇\n2. $ZM 🥈\n3. $BBIG 🥉\n4. $TSLA\n5. $PYPL\n6. $SQ\n7. $AMZN\n8. $GSAT\n9. $FB\n10. $AFRM\n\n#investing #stocks #wallstreetbets\n\nJoin the official Telegram for more frequent updates: \nhttps://t.co/d6SI8SpZyz https://t.co/LLAC231qlb',
#  '@FradeDuarte tsla',
#  '$ARKK inside month will be closed out tomorrow - betcha we start caring about the $arkk Buy and sells soon again\n\nI saw it in the whispers today everyone was bullish $TSLA lol https://t.co/0EIsOG6p0X',
#  '@cnbc (aka CNBS), @lorakolodny, @jimcramer, @andrewrsorkin @SaraEisen @ScottWapnerCNBC @Lebeaucarnews. Awaiting your story on Lil’ Michael Burry’s ill-fated short bet on $TSLA. Queen @CathieDWood! https://t.co/6SVni2tqYk',
#  '$TSLA Clean charts 🦾👽🚀🇺🇸 #Tesla @Tesla https://t.co/taTzrWVskp',
#  'via GerberKawasaki: Looks like the Bolt is dead. My guess they are better off just refunding all buyers than this attempt to fix a bad car.  $GM has failed in the EV game. Game over.  #tesla $tsla $tsla',
#  "@Commuternyc Yeah, I was only valuing $TSLA on the cars and energy (yes I know energy is lagging).  I don't think the stock reflects any of the autonomy or A.I. or any of that yet.",
#  '$TSLA is Golden',
#  '$TSLA Update on chart from last week. So we have nice uptrend after Bullish Cypher formation. Trend has stayed intact and we finally broke and held resistance (720s). Now we look for 743 (next resistance) before we get a hook n go 🚀 https://t.co/p6FVo923tj https://t.co/1p1cfihfNj',
#  '@Commuternyc Man, Looks like you have it all figured out.  You are short $TSLA then?',
#  '@AlternateJones Teach me your ways sensei! I have been holding 740 shares of $TSLA since 2018 but unfortunately I didn’t use options and margins…',
#  'Looks like the Bolt is dead. My guess they are better off just refunding all buyers than this attempt to fix a bad car.  $GM has failed in the EV game. Game over.  #tesla $tsla',
#  "$tsla it's only Monday https://t.co/MTxkGkAqTD https://t.co/QMi5xgceTd",
#  '8/30 - Monthly-Weekly-Daily Up order by Weekly from personal watchlist - $GLBE $MTTR $PLL $PYPL $ETSY $TQQQ $AAPL $SMAR $COUP $TSLA $FND $ESTC $TAN $INMD $U $TEAM $FB $AMZN\n\n#stocks #stockToWatch #study #stockscreener https://t.co/ZOVKaDXKCE',
#  '@Trendspider_J $TSLA $GOOGL $AMZN',
#  '@TradingWarz If anyone took your tsla idea they would be smiling so hard rn.',
#  '"Tesla (TSLA) Fremont Factory Checks Shows Activity \'Back to Normal\', Suggests \'Massive\' Q4 - Global Equities\' Chowdhry" https://t.co/lOrLv6QWzZ',
#  'おはようございます🌞\n米株myPF+0.29%\n対主要指数に負け\n\n買い増し $YANG\n PFは15%ほど縮小\n\n⤴️ $AAPL $TSLA $REGN $CRWD $FSLR $VGT $NVDA\n⤵️ $UPST $BAC $XOM $YANG $ZIM\n\n大型グロースで指数上げ\n相場は何故かゴン攻めの強気😳\n昨年9/3木曜日を彷彿させます😵\n#米国株 https://t.co/JwORiJlN4X',
#  'ポートフォリオの整理完了。\n\n銘柄数を約半数にした。\n\n完全に調整押し目待ち。\n\n#VTI と、観光セクターと #ZM  #CRWD #TSLA #NTR\n\nは残留。\n\nズームは腹括ってちょっと持つかな。\n\nこのままマーケットがズンズン上行ったら、僕だけ待ちぼうけです。\n\n皆さんの、短・中期的目線はいかがですか。',
#  '@FradeDuarte 1) $TSLA\n2) $SHOP\n3) $GOOGL',
#  '@Carwhorns @Trades_Grizzly You guys thinks TSLA can runs to $750?  This thing is nuts.  #teambull',
#  "@Commuternyc @garyblack00 I'm I correct in that your take is that $TSLA is like ENRON, and is in a bubble?\n\nSo it's overvalued, and a Fraud, in your opinion?\n\nSound about right?",
#  '$TSLA 🚂🚂🚂🚂🚂 https://t.co/7qv1aZ8No8',
#  '$tsla and Elon just solved the housing price crisis in America. Be thankful! https://t.co/eXxUJUj8jG',
#  "$TSLA Looking like a possible upwards wedge break here on the daily, nice AVWAP support hold and bounce when anchored to recent highs\n\nWent long late day today, love the setup here. Stop's underneath that AVWAP support https://t.co/7EMWMRwFOw",
#  'Los ojos hacen más ejercicio que las piernas. Se mueven unas 100.000 veces al día. \n\nPor eso $TSLA mañana abre con gap al alza.',
#  '@TheSonOfWalkley @squawksquare @JoeSquawk @BeckyQuick @SquawkCNBC They did this shit when tsla had the same market cap as all the other automakers what was the excuse then?',
#  "@Commuternyc @garyblack00 Well, I certainly admit I don't know everything.  But I do know some things about Tesla.  I understand a lot of the core tech.  If two analysts disagree on price, and one has no clue about the core Tech, they are less likely to be right.\n\nSimple as that.\n\n$TSLA",
#  '📊: 8/30/21 WEEKLY FOCUS LIST\n\n$AMD 8 \n$DLO 7 \n$ZI 6 \n$SNAP 6 \n$DOCS 5\n$PLTR 5 \n$DDOG 4\n$NVDA 3 \n$DIS 3\n$TSLA 3 \n$NET 3 \n$U 3\n$RIOT 3 \n$FIGS 3\n$LTHM 3\n...',
#  "$SMH (semiconductors), $XLF (financials), $HYG (high yield corporate bonds), $PAVE (infrastructure development) &amp; $MTUM ( $TSLA, $PYPL, $DIS etc.) hit new highs &amp; the breadth problem of 21 SEEMS TO BE fading. I'm almost 100% invested right now; 1 eye always towards the exit tho!",
#  '何って用事はないけど目が合った時にニコッとする女性いいよな。\n社内はディズニーの悪役みたいな人多いからさ🙄笑 https://t.co/0F7NeNFxXp',
#  '@AndrewYang @profgalloway How’s @profgalloway’s $TSLA short position doing?',
#  '@Zen_Options @ProblemSniper https://t.co/IBQhGWWEHn',
#  'Check out this account on OpenSea https://t.co/onmCkfR6Ld via @opensea $TSLA',
#  "Michael Burry is Koalemos but he thinks he's Cassandra. Unfortunate.\U0001f972 #MichaelBurry #Tesla $TSLA #Teslashort",
#  '@squawksquare @JoeSquawk @BeckyQuick @SquawkCNBC Because $tsla is a $700B+ company. When you’re top 10 in valuation, all eyes are on you. Unfair, but makes sense i guess :/',
#  '$TSLA - Tesla Receives Approval to Launch Four Variants of its Vehicles in India 🇮🇳\n\nhttps://t.co/uX0m5ODZAV',
#  'It’s coming! 🔥 \n\n$TSLA #Tesla https://t.co/kMteuAgvMK',
#  '@HeroDividend Selling $TSLA B4 THE BIG SPLIT!!!!! ERRRRR!!!',
#  '@ProblemSniper extremely',
#  '◆最高値からの値動き 8/31\nFacebook $FB: -0.2%\nApple $AAPL: -0.2%\nGoogle $GOOG: -0.7%\nMicrosoft $MSFT: -0.7%\nSquare $SQ: -6.0%\nPayPal $PYPL: -7.0%\nAmazon $AMZN: -9.3%\nOKTA $OKTA: -9.9%\nTesla $TSLA: -18.8%\nTwitter $TWTR: -19.9%\nDraftkings $DKNG: -20.3%\nZoom $ZM: -41.0%\n(4/4)',
#  'Stock: $TSLA - Tesla\n*** NEWS ***\nTesla: Waiting For Major Catalysts - Seeking Alpha\nhttps://t.co/xXbSwFpii4\nTry now the Best Pivot Point Calculator!! https://t.co/QAggKu4VvG\n#tradingview\n#stocks\n#stockstowatch https://t.co/Q8YYzwO5TC',
#  '$MRNA w/ Bearish Pennant as mentioned Friday.. down $11.39 this early am\nhttps://t.co/VyUY4pdbys\n\n$SPY $AMZN $AAPL $BA $NFLX\n$TSLA $AMD $ROKU $NVDA $FB\n$TWLO $PYPL $DOCU $CRWD $ETSY $SQ $MSFT $BABA $DKNG $BBIG $SPRT $CORE $PLNT $AMX',
#  '@MarkMoses777 @movingup2020 I would love to see your entry and exit on $TSLA if possible. It’s shot up so quick I got it late then dinged on the pullback',
#  'For reference, "peak performance" here is still a 0-60 time over 6 seconds. The id.4 is nice compared to ICE cars, but at the same time a total technical failure compared to any $TSLA model ever made. https://t.co/Qsp5fjGrU3',
#  '@garyblack00 I see why you pick 7/27, Gordon said  he would be shorting $TSLA tomorrow (on 7/26)\nhttps://t.co/rel8nWMwBm',
#  '@LordPente @garyblack00 Imagine watching a bubble stock like ENRON-Tesla thinking it was a measure of your IQ $tsla $tslaq #tesla',
#  'Bullish move in $SQ as price closed above the Aug 5 Anchored VWAP. $SNAP coming on top of the inside and managed to close above the MTD VWAP and 21 DEMA. $TSLA closed above 729.90 pivot . $TTD consolidating after earnings move and riding 50 DMA. $RIOT printed an inside day.',
#  '@garyblack00 Imagine watching a bubble stock thinking it was a measure of your IQ when in fact it was a measure of your stupidity $tsla $tslaq #tesla',
#  'In 2 weeks my $TSLA investment has netted me 2 years of “living expenses”.',
#  '#WallStreetBets Top Stock Mentions Today #WSB\n\n$SPY: 337\n$BABA: 214\n$CRSR: 172\n$GME: 135\n$GSAT: 91\n$ZM: 80\n$AAPL: 74\n$TSLA: 70\n$AMC: 68\n$BB: 66\n$PLTR: 57\n$ASTS: 53\n$NVDA: 50\n$HOOD: 40\n$AMZN: 38\n$AFRM: 36\n$AMD: 32\n$WISH: 32\n$CLOV: 30\n$QQQ: 19\n$PAYA: 17',
#  '$TSLA 先生がジワリ (ﾟ∀ﾟ)\n何だかんだでTSLAが最大ポジションなのでジワリでも寄与度がデカい件 https://t.co/SoctOt15jv',
#  '@GordonJohnson19 at his peak level of analysis. Wonderful job regarding $TSLA. https://t.co/TCPQo1BBeS',
#  "@Trendspider_J $TSLA buzzing tonight. Glad I'm locked in let's go!",
#  'I expect to see some big news come out this week with this amazing price action! I’m on the lookout $TSLA',
#  '$TSLA #BOT https://t.co/QH593iap7h',
#  '@vincent13031925 Huge news! Should be a great week for $TSLA 🚀🌙',
#  'Free discussion on Options trades \n\nLimiting your risk \n\nHow to look at technical analysis!\n\nhttps://t.co/rFu3nXh5YL\n\n$SPX $SPY $DIA $IWM $GLD $SLV $TSLA \n #optionstrading #trading #trader #options #stocks \n#daytrading #investor #swingtrading https://t.co/FPyaLVZCMu',
#  "Don't miss our next FREE OPTION TRADE.  Sign up for our Daily Free Trades at https://t.co/KXCL7sDR6o $NVDA $TSLA $GS $C $WFC $GOOGL $FB",
#  '$TSLA IS GONNA BLOW THE SHORTS OFF OF SHORTS COME TOMORROW',
#  '$penn $mara $fsr $tsla $opti $spy $aapl $pltr $hood $snap $fb $btbt $coin $gme $aal $dkng $mvis $sndl $spce $mara $nakd $nio $sunw $fubo  $amc $coin $amd $msft $wkhs\n\nWE ALERTED $NOVN at $.50 RAN TO $1.30 (160% GAIN)\n\nDAILY ALERTS\n\n$15 ONE TIME FEE\n\nBEAT THAT\n👇👇\n🚨LINK IN BIO🚨',
#  '$mRNA with a #MorningStar following a Bearish Pennant. https://t.co/XcdZG7Vt1S\n\n$SPY $AMZN $AAPL $BA $NFLX\n$TSLA $AMD $ROKU $NVDA $FB\n$TWLO $PYPL $DOCU $CRWD $ETSY $SQ $MSFT $BABA $DKNG $BBIG $SPRT $CORE $PLNT $AMX https://t.co/f7JC4x1ilQ',
#  '@alec_zamora $TSLA looks ready to rip some faces off',
#  '@rootslashbin Tsla broke out',
#  'Posted 10 charts tonight with more of a zoomed-out view as the monthly chart comes to a close tomorrow. \n\nHope these help with another perspective in the markets!\n\nGoodnight! :)\n\nReviewed:\n$AMZN \n$NFLX\n$DIS\n$GRWG\n$PLTR\n$SPOT\n$FUBO\n$CRM\n$TSLA\n$TWTR',
#  'About to buy more $TSLA 😫',
#  "Jumped in the market cold again and made some sloppy mistakes. Shoulda known - I usually get hurt when I don't stretch and warm up. $MRNA, $AAPL, $TSLA\n\n#BBTfamily #StockMarket #trading \n\nhttps://t.co/XyVGkKZFPT",
#  "Here's a good one from $TSLA CEO @elonmusk. https://t.co/HbuCt12i5d https://t.co/W4jlaEkDNC",
#  '私の甥っ子が行く幼稚園で友達のパパがコロナにかかったらしくて、休む園児が増えたそう🙄パパも大変だな。',
#  '$TSLA   Real price will come out soon; Follow price targets:..,..  \n\nhttps://t.co/SUOxzp8XEC',
#  '@WallStSai It’s nothing. $TSLA will crush the shorts',
#  "@garyblack00 I keep getting told I don't know how to read charts, and balance sheets.\n\nBut lots of $TSLA bulls do.\n\n$TSLAQ keeps saying Tesla is still just a car company.\n\nSo, obviously they have no clue what they are talking about.",
#  "@RichardJBardon - a hero with $24,000 worth of 2 fridges\n- a hero with TSLA deep ITM calls until next year \n- a hero with GOOGL deep ITM calls \n\na hero that we need but we don't deserve indeed.",
#  '$TSLA weekly\n\nLooks ready to absolutely rip this week.\n\nThis is one of those potential MASSIVE weekly breakouts I talk about. This train is about to leave station. https://t.co/svhFM8a8k6 https://t.co/hinFwVim4G',
#  'Recap from the weekly list : \n\n$PYPL 600% (1.00 -&gt; high of 7.00) 285C weekly\n$AAPL 200% (1ish -&gt; high of 3.95) 150C weekly\n$U 48% (2.98 -&gt; high of 4.43) 130C 9/17\n$TSLA 100% (3.3 -&gt; high of 6.73) 740C weekly\n$SQ 15% on re-entry into 275C weekly\nfdx,orcl,nclh,amd failed/negated',
#  'アルゴよ、それは恋じゃ。',
#  "$TSLA #TSLA Yea I wouldn't short this... https://t.co/1ZWC3Zc3Hf",
#  'Imagine being a $TSLAQ short and watching $TSLA grind higher every day (+13% since 7/27, NDX +4%) and your rear-facing metrics can’t tell you why?\n\nAs Berlin &amp; Austin get closer to opening, WS 2022 vol ests (1,480K vs Street 1,170K) and EPS ($9.80 vs Street $7.29) likely to jump. https://t.co/fqGLemSFmI',
#  "$TSLA - Tesla's Proposal to Reduce Import Duties Is Supported by Several Ministries of the Government of India 🇮🇳\n\nhttps://t.co/47R0U9uGSW",
#  'Still holding $NVDA and $GOOGL. I did miss $AMZN move. 😠 same watchlist published over weekend on my feed. \n\nHolding both into tomorrow. \n\nI added $TSLA at close. https://t.co/BDEMjEQtTt',
#  '$TSLA = deliver now, fix later.\n$LCID = get it right the first time.\n\nhttps://t.co/idFUfNj5xb',
#  'S&amp;P500 +0.43%\nRussell2000 -0.49%\nSOX +0.29%\nDJT -0.46%\nHYG +0.13%\nSTOXX600 +0.07%\nDAX +0.22%\nFTSE +0.32%\n\nFB +2.15%\nAMZN +2.15%\nAAPL +3.04%\nNFLX +1.30%\nNVDA +0.23%\nMSFT +1.29%\nGOOGL +0.41%\nTSLA +2.67% https://t.co/tyTBh7k1Vw',
#  '@35y10b 이따 떡 사먹으려구요 ㅋㅋㅋ',
#  '$TSLA customers throwing the bull shit flag at Musk’s lies and tone deaf response. https://t.co/pupTQLO4QZ https://t.co/lr5yWrbE8b',
#  '@U3VzCr65zYBnBeq ㅋㅋㅋㅋ 네~ 오늘 떡 하나 사드세요~',
#  'Oil shills paying main stream media to rehash old news on a big up day hoping to drive FUD.  $TSLA https://t.co/apFLcYj4Fw',
#  '@OhYeon12 그래두 오늘을 즐겨야죠~~ ^^ 예~',
#  '@muskinfluencer 아주 좋은 선택을 하셨네요~~~\n저도 최근에 +60%삼전, +70%카카오, +30%삼바, +20하이브 모두 정리하고 #TSLA #Bitcoin  샀습니다~\n이제 국내주식 아예 없어요~',
#  '$TSLA up +2.7% today👍\n\n$TSLA Sep 22 $1000 calls down 4.5% today\n$TSLA Jan 23 $1000 calls down 4.9% today \n🤔 https://t.co/udQMsi27Q7',
#  'Is Michael Burry still shorting $TSLA? Asking for a friend.',
#  "@TLPrivate_ Caught $DOCS on the reversal this morning and $GLBE as it moved up and over yesterday's high on good volume. Tried $PLTR but cut when it pulled back for small loss. Bot $FIGS and $TSLA since things were working, up a little both on tight leash for tmrw.",
#  'Read the replies to see how shitty $TSLA #Beta service to customers is. https://t.co/pupTQLO4QZ',
#  '$TSLA https://t.co/fJ4rJkmAQi',
#  '$TSLA 730 break was huge I think we could see 745 test by midweek',
#  'おはようございます。米国株サマリーです。指数はさらに高値更新、セクターは生活必需品。ETFはVUGグロースが好調です。個別株はなんと言っても $AFRM の爆上がり、$TSLAも好調。宇宙銘柄、ワクチンも下がりました。今日も頑張りましょう♪ https://t.co/oheooFCAoz',
#  'Posco launches nickel processing in Gwangyang \n#CanadaNickel \n#ESGThoughtLeader\n#NetZeroNickel \n#TM  #Nickel  $CNIKF $NOB.V $SHL.V $CNC.V  #EV #BatteryMetals   #Reddit $TSLA #ESG #ESGWatch  #Mining #ElonMusk #Glencore #BHP #Vale https://t.co/32D6SvjVhm https://t.co/cvupExAKB0',
#  '$TSLA   Real price will come out soon; Follow price targets:.,..  \n\nhttps://t.co/3gRXMqrHbW',
#  'Missed this breakout on $TSLA, but seems to just be stuck in a range since that break. Hoping to see it clear resistance around $780 before looking for an entry. \n\n#tradingview #missedthatboat #tesla https://t.co/a8F8tfyh4j',
#  '@KanaPU11 早速返信いただき有難うございます🙇\n\n昨年のジャフジャブ状態でもそうならば、今年は言わずもがなですね。\n\n昨年ブレイクしたあのTSLAの昨年の株価ですら、一旦売った方がいい結果でしたもんね。TSLAの利確もしようと思います。\nモデルナの買いは様子見します。',
#  '[Last 2 Hours]\n\nStocks Trending among Elite #fintwit Traders: \n1. $ZM 🥇\n2. $AAPL 🥈\n3. $BBIG 🥉\n4. $GSAT\n5. $TSLA\n6. $PYPL\n7. $SQ\n8. $AFRM\n9. $FB\n10. $AMZN\n\n#investing #stocks #wallstreetbets\n\nJoin the official Telegram for more frequent updates: \nhttps://t.co/d6SI8SpZyz https://t.co/rnxcOdodq6',
#  '@Miguel_Boggiano @JoseLChilavert_ Hola Mike!! Alguna recomendación de venta de acciones?? Así le pongo la escritura de la casa y los papeles del auto… compre TSLA, MELI y varias del MERVAL, cdo dijiste q había q vender… me estoy forrando. El Drapie Boggiano',
#  '$TSLA\n自動運転で帰ろうとしたの、おもろい https://t.co/rZIWk0v021',
#  '[Last 24 Hours]\n\nStocks Trending among Elite #fintwit Traders: \n1. $BBIG 🥇\n2. $TSLA 🥈\n3. $AAPL 🥉\n4. $AMZN\n5. $SPRT\n6. $AFRM\n7. $ANY\n8. $FB\n9. $AMD\n10. $KPLT\n\n#investing #stocks #wallstreetbets\n\nJoin the official Telegram for more frequent updates: \nhttps://t.co/d6SI8SpZyz https://t.co/5Ujzj74bQD',
#  '@WholeMarsBlog @elonmusk When wallstreet figures out how to invest in self driving, $TSLA will explode once again',
#  'MOST POPULAR RETAIL STOCK’S TODAY \n\n#1  $AAPL\n#2  $GSAT\n#3  $TSLA\n#4  $AMC\n#5  $KPLT\n#6  $BBIG\n#7  $AFRM\n#8  $FB\n#9  $NIO\n#10 $AMD\n\nSOURCE @BreakoutPoint',
#  'Really missed that TSLA play today for $110. Super goofy L.',
#  '👀🤔A $GM pára temporariamente de produzir o Chevy Bolt após o último recall #tesla $tsla https://t.co/JUak2EHr3g',
#  '#tsla in #dogemode 😉👍 https://t.co/QnNeo1cfn4',
#  "@funwithnumberz @montana_skeptic @TESLAcharts @DanTelvock @lorakolodny @StanphylCap @Paul91701736 Must be @NYSComptroller extending Elon's hiring deadlines again, so that NY Taxpayers don't recover the $44M penalty from $TSLA",
#  '@jeremyjudkins I just switched some of my $TSLA shares to Jan 20, 2023 $900 calls today. 😀😀😀',
#  'I sold all my $tsla shares today as I prepare to grab them $lcid shares y’all don’t want. I’ll take a couple hundred of them 😈',
#  'Biden screwups .rising inflation ,,no match for Fed free money..Markets were strong ,esp..  Nas stocks Amzn +72..Aapl +5 on new iphone 13.. will use satellites Tsla+23 on well used pattern ,Googl +15 .  Sept 6 Holiday ,no trading ,also start of Jewish Holidays .Friday Jobs report',
#  '"Thanks for bringing this up, because high-tech company wouldn\'t know about problems, if not tweeted to the CEO."\n\n$TSLA $TSLAQ https://t.co/zTvPXQ29nC',
#  'Wouldn’t be surprised to see $Tsla stock price double in the next 18 months',
#  '$TSLA Breaking a downwards rate of trend on an absolute and relative basis. Ideally want to see it above the mid April highs, but the first setup would be to hold ~720. https://t.co/8dElrIaP8Z',
#  "Well, my legs are pretty much shutting off randomly now.  But I'mma clean.\n\n$TSLA",
#  '@Amoirsp @seyedoption Such a broad statement… many entry opportunities today. AAPL and tsla both break key resistances for example',
#  'I really like how $TSLA tend to old customers with smoking fresh software updates.\n\nhttps://t.co/JhkNi2lZY0',
#  '@TrendSpider About to hit the golden cross on the weekly too, even more significant… been following this move for a few weeks… bought every dip that found support on the trend lines $TSLA https://t.co/RhdDxIPsq1',
#  'Unfair to fully qualify it as the system was only on for 10 billing day but $TSLA  solar saved $210+ in electric in that amount of time.',
#  '$TSLA (1 hour)\n\nTesting again the previous high. EMAs are coming and RSI going overbought.\n\nHigher lows as well.\n\nBuy Zone available on our Premium Channel, login to review.\n\n#TizyChartsTSLA\n\nDiscord : https://t.co/7r1xWRDD4X\nTelegram : https://t.co/ELgtLRHFSe https://t.co/lCoB9bAsey',
#  'تسلا \n\n$Tsla\n\nخلال ثلاثة اشهر فقط \n\nواحتمال قبل نهاية العام نشوف قمم جديدة \n\nالسالفة باختصار\n\n العجز الموجود في سواق الشرائح الالكترونية صنف تفوق ادارة شركات السيارات الكهربائية\n\nتتفوق تسلا في مواجهة التحديات معناته تحقيق ارقام ⬆️ واستحوذ على حصة اكبر من السوق في غياب المنافس',
#  '@RealChickenBoy9 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  'سهم من #الأسهم_الأمريكية جالس يسخن 👀\n\nاسمه $COMS , يعيبه فقط السيوله لذلك لا تدخل بما لا تتحمل خسارته ☠️\n\n#NASDAQ \n#السوق_الامريكي \n \n#MR_US\n$TSLA',
#  'Don’t fight it Robert, just jump on board the $TSLA train. There is room enough for everyone. https://t.co/A7rwTFmvEy',
#  'Our last 12 Swing Trades have been winners 🤯\n$BBIG +793%\n$DLPN +111%\n$HP +86% \n$COST +55%\n$F +45%\nIf you took just ONE contract of each trade you could’ve made $1,191. \nOur membership is just $13/Week. \n\n$KPLT $KURA $GSAT $RNXT $RY $TSLA $NIO $AMC $GME https://t.co/pCDy3oX5lC',
#  'My watchlist for tomorrow:\n$AAPL over 154, 155c\n$AMZN over 3440, 3500c\n$GOOGL over 2900, 2930c\n$TSLA over 740, 760c\n$SNAP over 75, 80c\n$SNOW over 300, 310c\n\n$GS under 409, 405p\n$HOOD under 42.5, 40p\n$TSLA under 729, 720p',
#  '@21stQuadrillion @HenryLGreenidge @verge Why? So you stop loosing money shorting $TSLA?',
#  'If you want some bangers primed to get moving off current levels , \ncheck out $HD $DPZ $COST $W \nMy top watches next couple weeks + everyone’s favorites $TSLA $ROKU',
#  '@TESLA_is_a_TREX @HeartDocTesla @elonmusk If young investors can buy a fractional share for $BTC, why not for $TSLA? I don’t get this notion that young investors can’t afford to invest in Tesla.',
#  '@UndoneHope lol  ..yes.. tsla +4 ..Googl +5 in After Hours trade',
#  '$AAPL $NVDA $TSLA $BYND $SNAP $DPZ $AA',
#  'One of many Tesla killers! Death by a 420 cuts $tsla $tslaq #tesla https://t.co/WegZC64stX',
#  "$FB Same Week $1.3 to $4 200%, next week's swing 4.3 to $9 100%\n$AMD $2.7 to $3.7 37% (Ran to around $4)\n$TSLA 730C $5.75 to $11 91% (Holding 1/2 Overnight)\n$AVGO $500 to $506.\n$UPST Gap &amp; Flush, couldn't get over $222 key level. https://t.co/TWDCchiv39",
#  'I wonder who tried to short $TSLA and got rekt here lmao https://t.co/am8et3aPZu',
#  '$BTT.X BOTTOM GEM. \n\n$SPY $TSLA $SHOP  $AMZN $NVDA $ROKU $EBAY $AMD $BB $DAL $DOW $QQQ $ZNGA $AAPL $ESE $SPCE $FCEL $TRIP $BYND $MRNA $NOK $OXY $CCL $CRON $DGLY $HTZ $PENN $GMBL $CRM $GNUS $BA $WKHS $FLIR $CREX $MARK $EOLS $BLU $NOVN $ABBV $AZUL $AMC https://t.co/qP7xlQcxjS',
#  '$TSLA 今日の上げの原因はいろいろあるけど、特にテキサスギガの10月生産開始の見通しがいい事とインドでテスラの4モデルが承認された事かなあ。あノルウェーでも先月テスラ1000台納車して一位だった。後は下のGaryのスレのリストで https://t.co/6qnpgtbGH4',
#  "@Neo_EimajOzear @Yrouel86 @Nilon75349784 Dive! Dive! Dive!\n\nI haven't seen any posts about $tsla from them recently, I'm guessing it's doing well, still above $700?",
#  '$TSLA https://t.co/hTMEuEBxZQ',
#  '@Russ49358367 @abel68702463 Yup. Fully agree!! End of month and September down month normally but TSLA finally cleared resistance and made higher high so fingers crossed. Possible all it wanted was the 78% fib level at 735 from way back 785 high but hope not. Hoping slight dip to lose for 750 pop',
#  '$TSLA winnings of initial #BTC investment🙌\n\n$494634986 (36.64 %) (Realized: 272 M)\n(Estimating an average buy price of $35000/BTC with now 38,700 BTC holdings $BTCUSD)\n#Tesla #Bitcoin #crypto',
#  '$TSLA https://t.co/ljlyZ9nhKq',
#  '$TSLA BEARS BE LIKE: 😢 😭 \n\n$NIO $LCID BOOM! BOP! BING! 🥬✅\nhttps://t.co/9qgsVyCmJl',
#  '$TSLA LOL I TOLD U IT WOULD RALLY OFF THIS NO MATTER WHAT ANYONE THINKS https://t.co/xtTPEMuLwQ',
#  'Trading Ideas: strategy for TSLA Tuesday 08/31/2021 https://t.co/3sGaHDYYR7 📈 FREE trade-of-week via ⟶ https://t.co/BCEHq7Ce2N https://t.co/EsXLCIk6cc',
#  "@alex_avoigt $GM CEO said in Feb chip/supply concerns not an issue for production. Government came out and doubled down in Aug and said it's easing up, no worries. $TSLA BMW and VW have said it is a longer term concern all along to their credit. https://t.co/GzZk086J2M",
#  'Besos retired to file billion-dollor lawsuit. Musk builds a humanoid before retirement $TSLA $AMZN',
#  '$TSLA one of the most mentioned on wallstreetbets over the last 7 days\r\rVia https://t.co/gAloIO6Q7s\r\r#tsla    #wallstreetbets https://t.co/d6GCcQ7pZW',
#  '\u2066\u2069 \u2066@fucktheshorts\u2069 PROTECT HIM AT AL COST $TSLA https://t.co/mtueJVnzNi',
#  '$BTC $ETH $SOL $SPY $TSLA $DOGE This is my favorite collection from Solanart\nhttps://t.co/w2osN7tLHK',
#  "You have to evaluate each setup. Several are a no-go, like stocks making repeated all-time highs.  Also, algo is dumb in that it doesn't factor in today maybe 5% up. Most of these setups are impossible. $AAPL $AMZN $TSLA $SPOT $XLY $DHR $INFO $PYPL $SE $BLL $TRI  #TSP1 https://t.co/O6voEsTYsF",
#  '$TSLA +2.7% https://t.co/o6yCyZNAae',
#  '$TSLA $750 Tomorrow? 🏃\u200d♀️🏃\u200d♀️🏃\u200d♀️',
#  'おはカピ🌞\nイベント通過後の週明けは大型グロースが大きく上昇📈 $AAPL $TSLA $FB $AMZN など2%↑の上昇となりました。一方で小型はやや軟調。そして全指数で出来高は引き続き減少傾向...あまり大きく動きたくはないですね。 ATH決算では $ZM が-11%と下落😱今週も頑張ってまいりましょう😇 https://t.co/K33fU4Lmxs',
#  '$TSLA confirmed to $780 in 2 days 💥 https://t.co/xbAMWKMH7k',
#  '@TLPrivate_ Also started a position in $TSLA as it broke the $729.90 pivot at a near perfect closing range on greater volume than any day last week.',
#  'Smart investors know that Tesla AI Day was the day $TSLA set itself apart from other EV makers. If other EV makers had better AI, they would have announced by now. Their silence means they haven’t even though about developing AI in 2021. 5+ yrs behind again. 😂 $F $GM #VW',
#  "He's probably gaslighting the Parts supply chain disruptions and chip shortage the auto industry is seeing right now. Just getting brake pads/filters is a problem for some OEMs. $TSLA https://t.co/LpbJ7n0Rfa",
#  'If this $TSLA break out holds, it’ll be the one of the best trades of 2021',
#  'Uhhhhh. \n$TSLA https://t.co/iMHQvxtUJ2',
#  'Tesla’s state of the art Autopilot safety system puts the driver in direct contact with first responders when necessary. $TSLA $TSLAQ https://t.co/o7G4vQENz0',
# ...
#  'Open Positions\n\nBuy Price&gt;Current Price\n\n$EDIT $65.19&gt;$61.80\n$AMD $106.20&gt;$111.32 \n$AAPL $149.90&gt;$153.12\n$NTLA $157.40&gt;$153.95\n$TTD $79.40&gt;$80.71\n$TSLA $698.60&gt;$730.91\n\nNo short positions',
#  '$TSLA - Tesla continues to move higher after-hours, Fib GP would be a lovely TP.  🚗🚗🚗🚗🚗🚗🚗 https://t.co/R1skklAKfq',
#  'Short $TSLA give me your money.',
#  "@HighFloor84 This awesome. Tell the guy who put this together thank you. Isn't $TSLA bidding on the power infrastructure for Texas?",
#  'I’ve gotta confess I was braced for a pull-back today as a little supply chain FUD over the weekend, but $TSLA is looking very strong. https://t.co/FYO1DIvy8m',
#  '𝗙𝗼𝘂𝗻𝗱𝗲𝗿 𝗹𝗲𝗱 companies, bucketed: \n\nSaaS/Tech: 💻☁️ - $TSLA $COIN $NVDA $SHOP $TWLO $SQ $PLTR $TTD $CRM $DDOG $APPS \n\nCloud/Security: ☁️🔐 - $NET $OKTA $CRWD $ZS\n\nHealthcare: 🩺🏥 - $SMFR $GH\n\nhttps://t.co/nFkxGHGOle',
#  '$tsla running ah\nNext\n745.11\n760.7\n785.94\n811.17',
#  'LFG $tsla',
#  '@Prophitcy TSLA going nuts!!!',
#  '$TSLA lol squeeze away',
#  '$TSLA probably hits 750 tomorrow.',
#  "Long a weird amount of $tsla sept 10th 750s since yesterday's close. It has only just begun. May god forgive them for what they are about to do",
#  '$TSLA gets approval for four models from India’s testing agencies https://t.co/5tldZtkWpy',
#  'Real strong performance by $AMZN after its gap down on July 30th...looking to fill the gap. Check out the MACD, RSI and bullish trend break.\n\n$AMZN $TSLA $NVDA $MSFT $AAPL $SPX $QQQ $GME $AMC https://t.co/moIv4sgkNv',
#  '$TSLA https://t.co/uijcq6cBKO https://t.co/I4CUCp7efS',
#  'Who has two thumbs and bought $TSLA calls today? https://t.co/s2zCqarDjj',
#  'Those after hours though  $tsla https://t.co/asvXCF5qOV https://t.co/05VW05WeBd',
#  '$BBIG $TAOP $JFK $CEMI $SPY $TSLA $SHOP $AMZN $NVDA $ROKU $EBAY $AMD $BB $DAL $DOW $Kodk $AAPL \nOver 75k+ people. Join now\nDiscord group https://t.co/C24h3Hy2kB',
#  '@sloth_investor @TrungTPhan car ownership\n$tsla',
#  "lmao at when @themotleyfool told me to sell $tsla at $540 pre split 12 months ago....... yeah!  Do you know what planet you live on motley? Do you know what's coming next?  #dumbmoney https://t.co/FMGuDsm3Ue",
#  'Thoughts and prayers with $TSLA shorts 😂',
#  '$tsla ripping ah',
#  'Wonderful start for the week. $AVGO $AAPL $AMZN $TSLA All green trades. Need 780 more to complete my #1kto10kchallenge I $TSLA gaps up tomorrow will be amazing!',
#  "@adamhoov @WholeMarsBlog @GordonJohnson19: You don't have the guts to short $TSLA. You know you'd lose every penny you still have...",
#  'Off to a good start for $TSLA\n\nAlso. This is the second week in a row TSLA up on a Friday/Monday combination. https://t.co/IgOzn63Wrv',
#  '@ValueAnalyst1 @28delayslater Strongly agreed $TSLA',
#  '@87AlwaysRed look at $TSLA AH!',
#  'Haha, so true, this would be a beastly portfolio, I reckon with plenty of diversification too as they all have different approaches… but biggest holding would definitely be $TSLA! https://t.co/K2KmATdD54',
#  '@TomsGuideFR La conduite autonome chez Tesla inclut-elle aussi la navigation sur cours d’eau? #TSLA https://t.co/lSFFthBMaN',
#  "@erpauditor TSLA for me is a bit of dead money here and the next 50%-100% is gonna be harder. I'd just trade it from time to time.",
#  'entered this in the a.m. - at .13 credit fill $TSLA https://t.co/UWQe1tgNoN',
#  'So far so good.. $NVDA, $TSLA, $AVGO already printed money. $TSLA up big! https://t.co/WhKT4bCqjy',
#  "@FedsShrtVol Look at those lovely monthly candles.. Why do u think $AMZN $NFLX $TSLA are pumping.. gotta preserve the structure. Which means they're not ready to crash the mkt yet",
#  'tehad_ shinfi_ R_go55 eadd_ lasagna_sumou パンツ何色？ぐへへ',
#  '@NlCKStocks $gsat tsla',
#  '@bourbonbuddy1 Careful now.  I saw someone in the industry last year saying the same thing about his friends being long TSLA calls - and that being a sure sign of a top in the market.  This is from July 2020',
#  '@StockMKTNewz $TSLA is the only company that has the infrastructure to maintain EV charging ports. GM, Ford, and companies like Fisker $FSR and Lucid $LCID are light years away. Anyone that says $TSLA will not dominate this space for 7-10 years I believe, is incorrect.',
#  'Today’s trades:\n$TSLA 740s 8.5 —&gt; 10 (holding some as these are next weeks)\n$SE 340s 4 —&gt; 5.48\n$ETSY 220s 2.00–&gt;3.4 \n\nIn $PLTR 27s .44 —&gt; .78 (holding position still.)',
#  '$TSLA is only in the beginning stages….. ￼so many things they are working on! https://t.co/ZarrY8IUpS',
#  'For all friends of technical analysis: \n\nToday, $tsla golden cross',
#  'WILL GO BACK OVER $1K soon\n\n$AAL $NAKD $DYNT $AMC $GNUS $UAVS $JAKK $NOVN $AMZN $AYRO $IMRN $NAK $BORR $GHSI $WTRH $NAKD $MARK $SHLO $NIO $HMHC $MDLY $JILL  $GRIL $JAGX $INO  $BYFC $TSLA $SPY $BOXL $AAPL $AYRO $BNGO https://t.co/i1sbyAWtm8',
#  '$TSLA after the $730... https://t.co/XN0moRuyTd',
#  'One in seven $TSLA poll answers owned stock during Dotcom. Lots of “young” investors. Or older investors that don’t like polls. Lol. https://t.co/UuPGLNxqsQ',
#  '$TSLA it’s already going. https://t.co/0QnI7MiX8V',
#  '$TSLA $750’s coming! 🔥',
#  '(8.31) Daily Plan (2/2)  🌞\n\n$MVIS  - Call &gt; 15.21   | Put &lt; 14.39\n$FROG - Call &gt; 39.28 | Put &lt; 38.33\n$VAL     - Call &gt; 67.99  | Put &lt; 66.05\n$CAKE  - Call &gt; 46.70 | Put &lt; 45.33 \n\n$SPY $NDX $IWM $QQQ $BTC $ETH $AAPL $TSLA $AMC $GME $CEI $GLBE $AMD $PLTR $SOL $ROOT https://t.co/y7aqpGxIW8',
#  '(8.31) Daily Plan (1/2)  🌞\n\n$DKNG - Call &gt; 60.80   |  Put &lt; 58.66\n$BA       - Call &gt; 222.40 | Put &lt; 217.53\n$BIIB     - Call &gt; 345.78 | Put &lt; 120.43\n$MARA - Call &gt; 40.77   | Put &lt; 37.65\n\n$SPY $NDX $IWM $QQQ $BTC $ETH $AAPL $TSLA $AMC $GME $BBIG $ANY $AMD $AFRM $FB https://t.co/QQS5bpxTiP',
#  'wow $TSLA 733.50 DE 715.0',
#  'Bear Forecasts\nAugust 30, 2021 13:15:00 PDT\n🐻🐻🐻🐻🐻\nticker : log change intraday\n$TTCF : 3.72\n$IYT : -1.26\n$EDU : 6.27\n$QLD : 1.72\n$AAPL : 2.47\n$GS : -1.44\n$VXX : 0.20\n$V : -0.72\n$ZM : -3.60\n$TSLA : 1.70',
#  '$TSLA closing over 728 will look for 744 if we can stay over 728 https://t.co/X2ExJr6ZOb',
#  'Thanks &gt; \nearn around $9k thanks\n\n$TSLA\n$FREE $VXRT $WKHS $TRIL $CCXX $LCA $OPTN $BLNK $INO\n$AMZN  $NKLA $SAVE $VRM $TRIL  $BBAR $STNG $GLUU $ZNGA $AAPL $BYND $MRNA $NOK $OXY $CRON $RCL $SPY $PENN $GMBL $CRNC $RGR $XLF $WFC $SPOT $UBER $GNUS https://t.co/t4Ipko2CVk',
#  '$TSLA $SPY $QQQ \n\nGood evening !\n\nOvernight swing\n\nTSLA 9/3 740 750 c \nBroke out and closed over 730 !\n\nGood luck bulls',
#  '$TSLA on the move AH next  $735/750/761',
#  '@NlCKStocks $TSLA',
#  'https://t.co/hqW2vlDtqB\n\n$TSLA',
#  '$TSLA Nice closing, heavy volume on weekly 750s. Watch for a move tomorrow. https://t.co/JVlHUvksvs',
#  '오늘, 정말 오랜만에 1M을 달성했다. 이제 0.1% 오르면 1K 이상, 1%오르면 10K이상 오르게 되어 대략적인 계산이 쉬워졌다. 앞으로 쭈욱가자. 10M까지도.\n$TSLA',
#  'I think, I am the only stupid $TSLA investor who buys only AHs.',
#  '@HeartDocTesla Money flowing to $TSLA',
#  '$TSLA Im sure im not the only one that saw/sees this. https://t.co/6Yzd8xiBxP',
#  '$tsla $tslaaq #tesla https://t.co/d1utqBcYwB',
#  'I picked up a total of 31 $TSLA shares today. Will seem like a gift after next split and rally onward to a $1-2-3 Trillion market cap.',
#  '$TSLA Rising Price and Volume\nDaily appearances since 2010: 156\nClose 5 days later ±:\nAvg: 2.22\nSD: 20.70\nWorst: -67.20\nBest: 174.35\n\n10 days later:\nAvg: 3.19\nSD: 25.26\nWorst: -164.58\nBest: 120.49\n\n30 days later:\nAvg: 7.88\nSD: 54.30\nWorst: -201.26\nBest: 324.64',
#  'Todays plays recap\n\n$AMD C lotto Swing 1.02-3.4 +240%\n$NVDA C Swing 6.3-13 +90%\n$ROKU C Swing 3.3-4.05 +22%\n$NFLX  C Swing 3.70-5.25 +42%\n$AMD C Spread Swing 0.3-0.65 +120%\n\n$AMD C DT 2.00-1.70 -15%\n$ABNB C DT 2.00-2.6 +30%\n$TSLA C DT 2.3-2.52 +10% https://t.co/glpcjBtekc',
#  'The levels provided by @EliteOptions2 for TSLA, FB and AAPL have been spot on.',
#  '$TSLA great move. Closing at the high. Moving after hours. Gapper tomorrow. https://t.co/dMqaVDsccq',
#  '#WallStreet 🇺🇸 Most Traded Contracts:\n\n$AAPL 3 September $155 Call\n$AAPL 3 September $153 Call\n$TSLA 3 September $750 Call\n$AAPL 3 September $150 Call\n$AAPL 10 September $155 Call\n$GSAT October $3 Call\n$AAPL 3 September $150 Put\n$BBIG September $8 Call',
#  '📈 Performance of some of the fellow traders of our Community .\n\nCalculated risk ,Great Analysis, Regular Alerts🚀\n\n🎉\n\n$SPY $TSLA $SHOP $AMZN $NVDA $ROKU $EBAY $BB $DAL  $GME $QQQ $AAPL $ESE $SPCE $FCEL $BYND $MRNA $NOK $OXY $CRON $DGLY $PENN $GMBL $CRM $BA $WKHS $NIO $TWTR https://t.co/phkvlPlj1R',
#  '$TSLA forming a golden cross in the daily',
#  '$TSLA looks gorgeous this week.',
#  "See what happens with $TSLA when the options are closed. It does what it should. You can witness that in AH's as it can't be manipulated like during market hours.",
#  '$TSLA after $730 algo are here for us this time https://t.co/ecZQeHwX9I',
#  '🔶 The day was mixed of gain and loss\n\n✅ But glad that many if not the all of our group were on the gain side 💪\n\n🚀\n\n $AAPL $NIO $SPY $WMT $FB $PT $PTON $GME $TSLA $MVIS $BABA \n$ATH $CRM $BLNK $GME $AMC $AMD $ADBE $RIOT $VXX  $UVXY $SQQQ $XOM $FUBO $PLTR $QQQ $OXY $CHWY $BBIG https://t.co/ECiYIpWg2r',
#  '$TSLA we have a Golden Cross on the daily today should open wider tomorrow. We also have some AH action for the first time in awhile. #Tesla https://t.co/ZWxYaKSp3j',
#  '$SPRT  = 1st Carbon Neutral Bitcoin Mining in the US 🇺🇸\n\nA lot of people do not know that this Epic Squeeze has todo with a  catalyst that  solves  @Elon_Musk  $TSLA concerns about the increase of use of fossil for mining... https://t.co/4cRfJZRZU1 https://t.co/h9Y1Z8JMJH',
#  'And buying $tsla $doge and $eth.  :) https://t.co/12Q0ZoLU2l',
#  "@eric_spooner_ @truth_tesla @spireland @ORStatePolice Everyone goes on about Teslas driving themselves because they ARE driving themselves (under supervision). People don't go on about Fords driving themselves because Fords suck at it (they can't negotiate a slight curve on a highway!!).\nNow for some pumping: $TSLA to the MOOON!! 😜",
#  '$TSLA Closed above resist first time in a while https://t.co/YDxCCgzqEI',
#  'We Alerted \n\n$TSLA today 250c $10 (scaling in, check watchlist for the idea) \n\n$OZSC $TLSS $VYST $BBRW $GAXY $TOPS $TPTW $OPTI $PCTL $AAPL $CCTL $CTS $HTBX $BOXL $TSLA   $MSFT $ABML $ETRF $NAK $PMCB $BRTXQ $HTBX $TRIL $NIO $NKLA $STHC $ATDS $GNUS $RNWF $TSOI $ESYL $HEMP $ALYI https://t.co/W5cPr0PuIZ',
#  '@PandaOptions @TrendSpider $TSLA is doing great so far after hours.. hopefully we hit the $750 range soon',
#  'Started trades today on $KNBE $ABNB and a partial on $TSLA... How about you?',
#  'All hydrogens explode AH w this: "Bank of America (NYSE: $BAC) compared the hydrogen market...to the smartphone market pre-2007 or the internet just before the dot-com boom." Boom. $plug $fcel $bldp $nkla $tsla $nio $aapl $msft $amzn $goog $fb $xom $spy https://t.co/hGoY5Ugivc',
#  'one runner $TSLA 750c',
#  '@squawksquare tsla jumped like a whole dollar this minute',
#  '@liamdenning @chrismbryant @bopinion he knows that TSLA itself is really only worth half of that',
#  'A,I team takes the guesswork out of trading and helps you to take your trading strategy to the next level! https://t.co/AhXJtt4ZP4\n\n$TSLA $AYRO $NKLA $SAVE $VRM $SHOP $BBAR $ZNGA $AAL $CACC $ESE $SPCE $FCEL $TRIP $BYND $MRNA $OXY $PENN $GMBL $SPY $KTOV $GNUS $BA $FCEL',
#  '$penn $mara $fsr $tsla $opti $spy $aapl $pltr $hood $snap $fb $btbt $coin $gme $aal $dkng  $mvis $sndl $spce $mara $nakd $nio $sunw $fubo $amc $coin $amd $msft $wkhs\n\nWE ALERTED $NOVN at $.50 RAN TO $1.30 (160% GAIN)\n\nDAILY ALERTS\n\n$15 ONE TIME FEE\n\nBEAT THAT\n👇👇\n🚨LINK IN BIO🚨',
#  '$TSLA still pushing up AH wow',
#  '$TSLA 750 tomorrow? 🤪 https://t.co/wQgZM8NcA1',
#  '$tsla on my mind &lt;3',
#  '$TSLA Based on various chip makers, the shortage in chips which directly restrains car production, will not disappear overnight = US auto inventories have fallen to the lowest level on record ... https://t.co/CIelPk6mWA',
#  '@TeslaJavi $TSLA gaining momentum. Price action the last month screams accumulation to me. Dips bought. Outperforming others in EV space. There is a not insignificant probability of a catch up rally near term. To $780 next stop. Then to ATH if momentum continues. I’m buying high or low.',
#  'Look like legit traders include this chat and making profits.  FREE Check out now... \n\n$NVAX  $TVIX $NVAX $UVXY $WFC $GSK $MMM $TOT   $AMD $BUD $FIS $NOW $HDB $C $RTX $UN $SPGI $BA $TD $BLK $INTU $BTI $MDLZ $CAT $BHP \n$SUNW  $SQQQ $POLA $TSLA $NKLA $NETE https://t.co/rlbbATlMim',
#  'On the 30th of August 2021. $TSLA awakens.',
#  '📈 Building brick by brick, our analysts motto!\n\n👏Pay a visit to our Community\n\n$CGM $APT $JAKK $DYNT $SPV $LMND $GNUS $GRAF $BIOL $NOVN $CHFS $AYRO $SOLO $CEMI $U $NBY $CLSN $CHFS $MARK $SHLO $NIO $DLPN $WKHS $CARV $SPY $AMZN $W $CGC $INO  $BYFC $TSLA $AAPL $MARA $BNGO $ABUS https://t.co/ez2fm7yO7E',
#  '@CurtRenz "Sir, $TSLA isn\'t an auto company"\n\n@elonmusk @WholeMarsBlog https://t.co/bjbGgSos1L',
#  '#WallStreet 🇺🇸 Today #Options Volumes:\n\n$AAPL 2.2M (78% call 23% put)\n$TSLA 1.2M (70% call 30% put)\n$BBIG 772k (86% call 15% put)\n$AMC 767k (74% call 26% put)\n$AMD 554k (79% call 21% put)\n$PLTR 535k (80% call 20% put)\n$NVDA 466k (64% call 36% put)\n$GSAT 429k (91% call 9% put)',
#  'TSLA closed at its highest level since April 27th, while its 50-day SMA (simple moving average) formed a Golden Cross as it pushed above its 200-day SMA. Technically quite encouraging.',
#  'Is $TSLA 2022 going to be a 2020 deja vu? \n\nJoin @AdamBerg4680 and myself tomorrow here on @TwitterSpaces for a deep dive with @garyblack00 into his $TSLA catalysts and more. \n\nhttps://t.co/5Lc6ToUz8P',
#  'GAFAMANT上昇\u3000\u3000GAFAM+AMD+NVDA+TSLA',
#  '$AMZN RUNNING PREMARKET. NEWS ARTICLE OUT!💸📈\n\n$SGMA $JFIN $NVTR $NNDM $DMPI $TER $MANH $EMMA $CNAT $ACST $SNAP $HOME $THC $AMD $TSLA $CGC $CRON $TLRY $HEXO $CTRM https://t.co/6HGmt3187n',
#  'Bear Forecasts\nAugust 30, 2021 13:13:00 PDT\n🐻🐻🐻🐻🐻\nticker : log change intraday\n$TTCF : 4.51\n$IYT : -1.26\n$ESTC : 2.55\n$EDU : 6.72\n$QLD : 1.73\n$AAPL : 2.51\n$GS : -1.44\n$VXX : 0.20\n$TSLA : 1.62\n$ZM : 2.00',
#  '$TSLA 730 P sold in last 5 mins https://t.co/KOaqL7SCqy',
#  'Bull Forecasts\nAugust 30, 2021 13:13:00 PDT\n🐂🐂🐂🐂🐂\nticker : log change intraday\n$TSLA : 1.62\n$AAL : -3.43\n$WKHS : -0.61\n$NVAX : 3.95\n$RKT : -1.03\n$DOCU : -0.42\n$TQQQ : 2.40\n$AFRM : 1.73\n$AAPL : 2.51\n$BNTX : -0.94',
#  'TSLA looking interesting again as a short term play. Not  a long term bull on this one.',
#  '$TSLA almost $6b in call flow on the day. I’ve never seen so many golden sweeps in my life. Insane day #Tesla #tsla https://t.co/0x1bhB756x',
#  'Unusual Options Activity $AAPL $GSAT $WKEY $SDC $BBIG $ASO $LUV $DIDI $ROOT $AEO $FB $TSLA $WDAY $NVDA $CLOV $KHC $DASH $WFC $HOOD $HOFV $AMZN $WFC https://t.co/jusgBNv2qQ',
#  '$TSLA I missed the entry above $715 for a run towards. $725. I was waiting for this bounce and I missed it when it happened.\n\nCongrats if anybody capitalized today. Also, the swing entry from $653.58 is doing awesome. Congrats if anybody still riding it. I have closed it already. https://t.co/fYDrtl0WjU',
#  'This should be nice tomorrow $tsla 750c $$$',
#  '@trhototc @TheRealDrip2Rip @ATL_EN Always slow and steady . You know I only took one play today I was just helping so many people … okay I took spy and spx but they were short ones … Bc I had been waiting for amzn for a month … I did grab TSLA for a min but I was too focused on the behemoth lol',
#  "Today's most active options:\n\n$AAPL 2,277k - 22% put. 78% call\n$TSLA 1,146k - 30% put. 70% call\n$BBIG 787k - 14% put. 86% call\n$AMC 784k - 26% put. 74% call\n$AMD 568k - 21% put. 79% call\n$PLTR 538k - 20% put. 80% call\n$NVDA 476k - 36% put. 64% call\n$GSAT 438k - 9% put. 91% call",
#  'Trading Ideas: TSLA to $777 https://t.co/bF3qbUDy0m 📈 FREE trade-of-week via ⟶ https://t.co/BCEHq7Ce2N https://t.co/C6MawVATHm',
#  ...]

# %%
import re
import numpy as np

stopwords = ["need","break","still","year","look","going","make","u","share","one","day","week","new","market","now","amp","s","for", "on", "an", "a", "of", "and", "in", "the", "to", "from","tsla","tesla","will","see",'tslaq',"think","today","stock"]
res = []
for tweet in tweet_text_list:
    if type(tweet) == np.float:
        continue;
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    res.append(temp)
res
# Out:
# ['zm 300 00 275 00 coming fast spx spy dia iwm gld slv',
#  'example was it had inside bar doesn t have many those when alert hit few times i was comfortable take trade hope it makes sense',
#  'this harmonic 650 780 remember this tweet called it 8 17',
#  'yes please thank very much',
#  'what your pt by 2025',
#  'elon liked this tweet',
#  'equity idea highlights gme long 7pts sprt long 5pts afrm long 5pts total long 4pts nvax long 2pts bfv long 1 5pts live stream 24 7 chat support stocks options promos 50 off weekly ag50 25 off monthly trading ag25',
#  'back 900',
#  'lets hope this wasnt just tease',
#  'first recap two weeks it good be back spy qqq aapl amd pltr',
#  'i shared this trigger list last took patience but we got it t 713 trigger bring 731',
#  'so part shortage done nice',
#  'moon that all dd i needed',
#  'yeah longer consolidation stronger breakout upside',
#  'musk variant',
#  'abml with gun ryan melsert ceo their first kind closed loop lithium battery recycling plant about be built abml',
#  'selling puts',
#  'bngo medical field',
#  'i m watching zm docu mq mrna asml',
#  'what trade small cap shorty was its monday we were given lot opportunities after doing research about 60 stocks this morning here are just few we did live aj crwd ater bbig root mrna bntx mq',
#  '1 08 2 67 rprx 0 48 blde 3 14 apps 2 59',
#  'gps 10b cap with ptra arvl wix sklz open hood lev chpt idex grpn z ggpi wish sofi lcid tbla mvst bark f fsr amc spy eth nio baba btc clov aapl pltr gme qs ba spce doge plug fb nvda lgf',
#  'moon i am waiting days nights it lol',
#  'personally like sq msft amzn morning tomorrow but we what has prepared us',
#  '1k',
#  'how about banning selling non existent product like say fsd',
#  '',
#  'bbig kplt arvl wix sklz open hood lev idex grpn z ggpi wish sofi lcid tbla mvst bark f fsr amc spy eth nio baba btc clov aapl pltr gme qs ba spce doge plug fb',
#  '750c',
#  'closed highest since apr 26 2021 at 730 91 687 730 looks good near term since aug 1 it gave chance enter at 665 levels',
#  'aapl bullseye works extremely well trending days this another buy call trade idea august 27th are up like 300 average obviously im cherry picking here but even if i dont returns over last few days are crazy fb iwm msft',
#  '1 add 2 se add 3 nvda',
#  'lt 1 gt 9 p 2 67 730 91',
#  'someone has short position lol',
#  'buy dip',
#  'o',
#  'speed',
#  '',
#  'stocks trending among elite traders 1 2 bbig 3 aapl 4 pypl 5 amzn 6 sq 7 afrm 8 fb 9 zm 10 gsat join official telegram more frequent updates',
#  'our worked making move previous close 712 730 spy next pt 750 by friday join our team start making money your aapl or device anywhere world',
#  'stocks trending among elite traders 1 bbig 2 3 aapl 4 amzn 5 sprt 6 afrm 7 any 8 fb 9 kplt 10 amd join official telegram more frequent updates',
#  'real price come out soon follow price targets',
#  '4 top trades tuesday afrm fb zm',
#  'ptra best i kplt arvl wix sklz open hood lev chpt idex grpn z ggpi wish sofi lcid tbla mvst bark f fsr amc spy eth nio baba btc clov aapl pltr gme qs ba spce doge plug fb nvda',
#  'go go go pt 3000',
#  '',
#  'heres primer every be different terms price ex every 20 dollar move up or down matters anything below is noise you dont use this option trading just commons time is non factor',
#  'keep listening rest media competition is coming gm',
#  'my management school academic friends working finance sector understanding valuation is blasphemy it just violates every rule they have learnt so far i investing they never accept that they are traditionally bad identifying innovative companies',
#  'elon musk liked tweet owners online',
#  'deadweight has its intrinsic value can add lot more load passengers soon meet its deadend',
#  'well shorts had 3 good months short so i theyre good is not moving like it used it took entire month back forth dip alas 725 again its been rebuilding channel since mid may finally moving higher',
#  'etf etf',
#  '',
#  'electric vehicle etf driv holds qcom intc aapl nio driv formed wave 1 2 march 2020 low then went wave 3 rally that ended at 28 before putting wave 4 at 23 6 retracement if driv gt 24 90 wave 5 target is 33 50 then 38 3 6m',
#  'super breakout',
#  'this is way hedge funds get away with fraud brokers helped them with easy borrow read what its about sprt gme amc gtii koss plug riot bynd gtii pton fcel nwbo eyes ekso bbig root',
#  'faster rise faster rise when bull getting more more margins',
#  'entry calls above 730 which is already valid targets 750 760 780 sl below 724 entry puts below 712 targets 698 679 sl above 717 after every target is reached that becomes your stop loss',
#  'picks 4 top trades tuesday afrm fb zm',
#  'once establish plant exports be giga shanghai giga india asian middle east australia this picture changes you less exports china',
#  'aapl ath goog msft w',
#  'learn more at story gnid cgnh dynt aryc sndd ozsc ctyx llbo rscf dis bby bft sbe spy qqq pltr psth sbe jmia wkhs',
#  'watch model plaid is world fastest coolest sedan youtube',
#  'qqq uber 2 7 2 67',
#  'aapl nvda sq all incredibly bullish darkpools unreal',
#  '30 31 gt 100k 6 4k profits last friday 5 7k profits 12k just matter 2 days mq short big money astr short afrm short alerts entries exits all inside discord join us spy nvda aapl mrna amc gme',
#  'multiple bullish price obj 790 980 this be negated if prints 645',
#  'most optimistic this weekends news coverage 1 amd advanced micro devices 2 lmt lockheed martin 3 msft microsoft 4 5 ibm ibm 6 goog google 7 doge dogecoin 8 qcom qualcomm 9 btc bitcoin 10 t at t',
#  'man do i love this weekly chart saying we keep rolling this is just beginning personally been holding since mid 650s it doesn t disappoint macd positive ready flight',
#  'was good play i misses as well',
#  'car motor trend killer lol competition my',
#  'are you short or holding puts',
#  'seems like big problem me gm is better stop dicking around give back money owners tell them back',
#  'just fact that media govt is trying its hard crush it very bullish sign others pltr sofi',
#  'weekly breakouts can be very explosive just sayin',
#  'corkscrew life runs ai',
#  'i cut loss already n put into right away seems can recover days',
#  'you future earnings are nonsense pe 72 isn t cheap tm current pe 9 you embarrass yourself',
#  '378 0 2 36943 36 138891 12157 spyd 2200 30360 52 11 389 5 uber 50 463 31 hdv 334 5203 19 abnb 22 425 14 qlyd 190 91 2',
#  'this hasnt happened very long time',
#  'mrna w bearish pennant as mentioned friday spy amzn aapl ba nflx amd roku nvda fb twlo pypl docu crwd etsy sq msft baba dkng bbig sprt core plnt amx',
#  '',
#  '2021 08 30 out resistance level daily 1 4 2021 08 30 spot avlr irdm',
#  'it was over it 4 5 separate times 2200 hodl jk im paper account',
#  'ross gerber gary black cathie wood like 3 ppps pod',
#  'nvnxf emhlf as always dyor',
#  'btc tqqq sq arkk maybe msft maybe unpopular opinion',
#  '',
#  'tuesday watchlist pt 2 1 strong breakout close above resistance next targets 760 780 2 nine 2 4 breakout 3 kala 3 3 support breakout over 3 6 4 ensv squeeze over 1 26 5 gme flagging daily 227 test 300 let bank big this',
#  'freedom stocks watchlist tomorrow enph run chpt oeg',
#  'me as well i guess most us investors are stupid until we are not',
#  'but i don t outsmart this appl attempting potential base breakout while nvda broke out last if we don t major reversals those names indexes end up being fought higher tough major downside that tape outside intitial moves',
#  '8 30 spx aapl afrm vix mrna',
#  'daily pretty much as you have it',
#  '',
#  'i guess most hf analysts do not know how value growth cokpany specifically such as its always fun you breaking ice them thank usual insights',
#  'lol dancer lycra please just stop',
#  'this line explanation valuation',
#  'anyone gonna go out limb say 800 this that 10 move over next 4 days',
#  '',
#  'sold more shares 725',
#  'simple human emotion peer pressure fomo that people dream up scenarios unreal growth earnings reality is is ugly bubble like any bubbles when it burst it be so stupidly clear why',
#  'grain salt but this reddit poster says their bolt went up flames at 2am while parking lot not plugged turned off whatever that means bolt gm',
#  'i remember greg he panic sold his way back he blocked me while ago calling out his bs i didn t know he already stooped this level idiocy',
#  '8 30 2 macd nxpi macd mq di macd pypl di upst atlc crwd zs ftnt docu macd twlo macd',
#  'watch list started tomorrow calls or puts or either c spy p msft c dis c zm e but maybe calls after such dramatic drop twtr possible breakout up watching closely',
#  'drove through 4 countries last this is what i can tell you about netherlands amsterdam has more them france paris has less hardly spotted any belgium brussels has less as well germany every city has more them',
#  '2021 08 30 us aapl fb',
#  'i dont that was mainly due robinhood similar free trade brokers though i ton people genuinely thought was be fail which given history auto startups was good bet didnt work out shorts though',
#  'most mentioned this weekends finance news coverage 8 28 8 29 1 aapl 2 3 goog 4 amzn 5 msft 6 fb 7 leo 8 nvda 9 btc 10 ibm bonus coin',
#  'start m1 finance account automated investing daily weekly monthly best all you can borrow 35 ltv your portfolio value at incredible 2 interest reinvest into dips plateau along with consistent automated investing',
#  'has 79 all ev registered united states where is competition thanks',
#  'gtii amc gme sprt xxi adil fcel plug mara koss eyes ekso bbig root bb kodk pton nwbo cvm veri any nkla nnox dpw good quick read about people who we pay protect us their thoughts',
#  'auph aup fair value 63 01 usd after getting phase 3 fda approval spy qqq iwm vix fb aapl amzn goog msft nio dkng penn mara riot baba spce cgc tlry acb apha gme pltr zm bb mmed amd intc cciv',
#  'lyft not everything is green me but i like gl amd spy intc baba low fb sq qqq fsly zm ba jnj nio twtr msft pypl qs spce atvi tmus bac pins cgc twlo snap f ge gm',
#  '',
#  'no wonder musk went texas',
#  'interesting 37 5 gives you 5 x 5 years nothing beats so it has all 5 top spots 1 2 3 4 5 6 btc 7 pltr 8 ark etf',
#  '',
#  'starting strong amzn fb pypl',
#  'bullish',
#  'cc',
#  'before fsd is available',
#  'guy i worked with 15 years ago who runs hf dm d me asked you grew up at bernstein you re so disciplined about valuation how do you like i dm d him back at 74x fy 22 eps with 55 volume eps growth between 2025 it dirt cheap no response',
#  'when is getting back 900 based your charts shit',
#  'so youre saying is overvalued i would disagree with that if true',
#  'winnings initial investment 477797786 35 39 realized 272 m estimating average buy price 35000 btc with 38 700 btc holdings btcusd',
#  'trade ideas fb 385c over 380 targets 384 389 392 396 support 372 367 361 750c over 735 targets 750 761 781 support 720 708 700 691 aapl amzn shop nvda spx gme amc nflx googl nio roku more plans are posted our private twitter',
#  'sing fire solar stocks be fire just getting started spy amd fb aapl qqq amzn nvda ba baba nflx twtr aal nio oxy ccl uso dal ino twlo ugaz dis roku vxrt codx djia spx tlry sq msft gld bynd srne spce',
#  'i ve got reasonable doubt he must have secret account otherwise he couldn t have said this because i m very certain he checked out export as well',
#  'pltr 220 pf qqq',
#  'fan index 8 31 point 204 32 1 77 30 marqeta mq 4 61 apple aapl 3 04 2 67 facebook fb 2 15 zoom zm 1 96 1 4',
#  'highest close last 126 days',
#  '720c trigger aal 20p trigger pins 56p trigger wfc 49p trigger',
#  '',
#  'i bought these lcid eth',
#  'my very first trades was brando call which happened be my biggest trade date his levels documents provide very clear picture his tactics trading i have referred multiple friends never heard negative thing back',
#  'gt that but open leaps sq',
#  '4 top trades tuesday afrm fb zm bears were caught offside friday betting that fed would say something derail rally opposite was true as p 500 surged all time highs that train continued without stopping monday',
#  'i havent seen that but okay im not sure how youd know with certainty what caused price move but i guess ill take your word it',
#  '',
#  'lmfaooooo just as goes over 700',
#  '2000 p500 10 afrm duol skyt zm dlo mrna bntx 8',
#  '734 ah looking solid',
#  'next resistance targets 750 770 must hold 720 keep momentum close below 712 upside move stalled other support resistance levels as marked',
#  'strategy tuesday 08 31 2021 long or short it with btc trade8',
#  'plays aapl 10sep21 157 5 c 0 50 e c 10sep21 745 c 7 57',
#  'rixh ass i have about 420 option contracts',
#  'october 2018 elon musk aim cover all regions na not just big cities within 3 6 months',
#  '',
#  'big aapl amzn fb',
#  'congrats your portfolio holdings 630 gt 734',
#  'cant wait expedite service center openings stories 3 2',
#  'ross your thoughts companies that produce cars but not power source having build out supply chain seems like grew up sourcing their power materials oems have always relied big oil do oems have that sort house talent compete w',
#  '1 3 sp faangm ba pmi eu cfd 18 0 05 35418',
#  'watchlist tomorrow 10 likes 5 retweets ill post another tomorrow 750c gt 730 roku 370c gt 366 4 350p lt 351 2 dis 185c gt 180 6 sq 280c gt 272 4',
#  'wow how strong this trend line has held weekly since mar 2020',
#  'great start this',
#  'watchlist bbig nvda aapl pfe mrvl pton sava gsat ater sprt afrm nna spy',
#  'stocks trending among elite traders 1 aapl 2 zm 3 bbig 4 5 pypl 6 sq 7 amzn 8 gsat 9 fb 10 afrm join official telegram more frequent updates',
#  '',
#  'arkk inside month be closed out tomorrow betcha we start caring about arkk buy sells soon again i saw it whispers everyone was bullish lol',
#  'aka cnbs awaiting your story lil michael burry ill fated short bet queen',
#  'clean charts',
#  'via gerberkawasaki looks like bolt is dead my guess they are better off just refunding all buyers than this attempt fix bad car gm has failed ev game game over',
#  'yeah i was only valuing cars energy yes i know energy is lagging i dont reflects any autonomy or i or any that yet',
#  'is golden',
#  'update chart last so we have nice uptrend after bullish cypher formation trend has stayed intact we finally broke held resistance 720s we 743 next resistance before we get hook n go',
#  'man looks like you have it all figured out you are short then',
#  'teach me your ways sensei i have been holding 740 shares since 2018 but unfortunately i didn t use options margins',
#  'looks like bolt is dead my guess they are better off just refunding all buyers than this attempt fix bad car gm has failed ev game game over',
#  'its only monday',
#  '8 30 monthly weekly daily up order by weekly personal watchlist glbe mttr pll pypl etsy tqqq aapl smar coup fnd estc tan inmd team fb amzn',
#  'googl amzn',
#  'if anyone took your idea they would be smiling so hard rn',
#  'fremont factory checks shows activity back normal suggests massive q4 global equities chowdhry',
#  'mypf 0 29 yang pf 15 aapl regn crwd fslr vgt nvda upst bac xom yang zim 9 3',
#  '',
#  '1 2 shop 3 googl',
#  'you guys thinks can runs 750 this thing is nuts',
#  'im i correct that your take is that is like enron is bubble so its overvalued fraud your opinion sound about right',
#  '',
#  'elon just solved housing price crisis america be thankful',
#  'looking like possible upwards wedge here daily nice avwap support hold bounce when anchored recent highs went long late love setup here stops underneath that avwap support',
#  'los ojos hacen m ejercicio que las piernas se mueven unas 100 000 veces al d por eso ma ana abre con gap al alza',
#  'they did this shit when had same cap as all other automakers what was excuse then',
#  'well i certainly admit i dont know everything but i do know some things about i understand lot core tech if two analysts disagree price has no clue about core tech they are less likely be right simple as that',
#  '8 30 21 weekly focus list amd 8 dlo 7 zi 6 snap 6 docs 5 pltr 5 ddog 4 nvda 3 dis 3 3 net 3 3 riot 3 figs 3 lthm 3',
#  'smh semiconductors xlf financials hyg high yield corporate bonds pave infrastructure development mtum pypl dis etc hit highs breadth problem 21 seems be fading im almost 100 invested right 1 eye always towards exit tho',
#  '',
#  'how short position doing',
#  '',
#  'check out this account opensea via',
#  'michael burry is koalemos but he thinks hes cassandra unfortunate',
#  'because is 700b company when you re top 10 valuation all eyes are you unfair but makes sense i guess',
#  'receives approval launch four variants its vehicles india',
#  'it coming',
#  'selling b4 big split errrrr',
#  'extremely',
#  '8 31 facebook fb 0 2 apple aapl 0 2 google goog 0 7 microsoft msft 0 7 square sq 6 0 paypal pypl 7 0 amazon amzn 9 3 okta okta 9 9 18 8 twitter twtr 19 9 draftkings dkng 20 3 zoom zm 41 0 4 4',
#  'news waiting major catalysts seeking alpha try best pivot point calculator',
#  'mrna w bearish pennant as mentioned friday down 11 39 this early am spy amzn aapl ba nflx amd roku nvda fb twlo pypl docu crwd etsy sq msft baba dkng bbig sprt core plnt amx',
#  'i would love your entry exit if possible it shot up so quick i got it late then dinged pullback',
#  'reference peak performance here is 0 60 time over 6 seconds id 4 is nice compared ice cars but at same time total technical failure compared any model ever made',
#  'i why you pick 7 27 gordon said he would be shorting tomorrow 7 26',
#  'imagine watching bubble like enron thinking it was measure your iq',
#  'bullish move sq as price closed above aug 5 anchored vwap snap coming top inside managed close above mtd vwap 21 dema closed above 729 90 pivot ttd consolidating after earnings move riding 50 dma riot printed inside',
#  'imagine watching bubble thinking it was measure your iq when fact it was measure your stupidity',
#  '2 weeks my investment has netted me 2 years living expenses',
#  'top mentions spy 337 baba 214 crsr 172 gme 135 gsat 91 zm 80 aapl 74 70 amc 68 bb 66 pltr 57 asts 53 nvda 50 hood 40 amzn 38 afrm 36 amd 32 wish 32 clov 30 qqq 19 paya 17',
#  '',
#  'at his peak level analysis wonderful job regarding',
#  'buzzing tonight glad im locked lets go',
#  'i expect some big news come out this with this amazing price action i m lookout',
#  '',
#  'huge news should be great',
#  'free discussion options trades limiting your risk how at technical analysis spx spy dia iwm gld slv',
#  'dont miss our next free option trade sign up our daily free trades at nvda gs c wfc googl fb',
#  'is gonna blow shorts off shorts come tomorrow',
#  'penn mara fsr opti spy aapl pltr hood snap fb btbt coin gme aal dkng mvis sndl spce mara nakd nio sunw fubo amc coin amd msft wkhs we alerted novn at 50 ran 1 30 160 gain daily alerts 15 time fee beat that link bio',
#  'mrna with following bearish pennant spy amzn aapl ba nflx amd roku nvda fb twlo pypl docu crwd etsy sq msft baba dkng bbig sprt core plnt amx',
#  'looks ready rip some faces off',
#  'broke out',
#  'posted 10 charts tonight with more zoomed out view as monthly chart comes close tomorrow hope these help with another perspective markets goodnight reviewed amzn nflx dis grwg pltr spot fubo crm twtr',
#  'about buy more',
#  'jumped cold again made some sloppy mistakes shoulda known i usually get hurt when i dont stretch warm up mrna aapl',
#  'heres good ceo',
#  '',
#  'real price come out soon follow price targets',
#  'it nothing crush shorts',
#  'i keep getting told i dont know how read charts balance sheets but lots bulls do keeps saying is just car company so obviously they have no clue what they are talking about',
#  'hero with 24 000 worth 2 fridges hero with deep itm calls until next hero with googl deep itm calls hero that we but we dont deserve indeed',
#  'weekly looks ready absolutely rip this this is those potential massive weekly breakouts i talk about this train is about leave station',
#  'recap weekly list pypl 600 1 00 gt high 7 00 285c weekly aapl 200 1ish gt high 3 95 150c weekly 48 2 98 gt high 4 43 130c 9 17 100 3 3 gt high 6 73 740c weekly sq 15 re entry into 275c weekly fdx orcl nclh amd failed negated',
#  '',
#  'yea i wouldnt short this',
#  'imagine being short watching grind higher every 13 since 7 27 ndx 4 your rear facing metrics can t tell you why as berlin austin get closer opening ws 2022 vol ests 1 480k vs street 1 170k eps 9 80 vs street 7 29 likely jump',
#  'teslas proposal reduce import duties is supported by several ministries government india',
#  'holding nvda googl i did miss amzn move same watchlist published over weekend my feed holding both into tomorrow i added at close',
#  'deliver fix later lcid get it right first time',
#  'p500 0 43 russell2000 0 49 sox 0 29 djt 0 46 hyg 0 13 stoxx600 0 07 dax 0 22 ftse 0 32 fb 2 15 amzn 2 15 aapl 3 04 nflx 1 30 nvda 0 23 msft 1 29 googl 0 41 2 67',
#  '',
#  'customers throwing bull shit flag at musk lies tone deaf response',
#  '',
#  'oil shills paying main stream media rehash old news big up hoping drive fud',
#  '',
#  '60 70 30 20',
#  'up 2 7 sep 22 1000 calls down 4 5 jan 23 1000 calls down 4 9',
#  'is michael burry shorting asking friend',
#  'caught docs reversal this morning glbe as it moved up over yesterdays high good volume tried pltr but cut when it pulled back small loss bot figs since things were working up little both tight leash tmrw',
#  'read replies how shitty service customers is',
#  '',
#  '730 was huge i we could 745 test by midweek',
#  'etf vug afrm',
#  'posco launches nickel processing gwangyang cnikf nob v shl v cnc v',
#  'real price come out soon follow price targets',
#  'missed this breakout but seems just be stuck range since that hoping it clear resistance around 780 before looking entry',
#  '',
#  'stocks trending among elite traders 1 zm 2 aapl 3 bbig 4 gsat 5 6 pypl 7 sq 8 afrm 9 fb 10 amzn join official telegram more frequent updates',
#  'hola mike alguna recomendaci n de venta de acciones as le pongo la escritura de la casa y los papeles del auto compre meli y varias del merval cdo dijiste q hab q vender me estoy forrando el drapie boggiano',
#  '',
#  'stocks trending among elite traders 1 bbig 2 3 aapl 4 amzn 5 sprt 6 afrm 7 any 8 fb 9 amd 10 kplt join official telegram more frequent updates',
#  'when wallstreet figures out how invest self driving explode once again',
#  'most popular retail aapl gsat amc kplt bbig afrm fb nio amd source',
#  'really missed that play 110 super goofy l',
#  'gm p ra temporariamente de produzir o chevy bolt ap o ltimo recall',
#  '',
#  'must be extending elons hiring deadlines again so that ny taxpayers dont recover 44m penalty',
#  'i just switched some my shares jan 20 2023 900 calls',
#  'i sold all my shares as i prepare grab them lcid shares y all don t want i ll take couple hundred them',
#  'biden screwups rising inflation no match fed free money markets were strong esp nas stocks amzn 72 aapl 5 iphone 13 use satellites 23 well used pattern googl 15 sept 6 holiday no trading also start jewish holidays friday jobs report',
#  'thanks bringing this up because high tech company wouldnt know about problems if not tweeted ceo',
#  'wouldn t be surprised price double next 18 months',
#  'breaking downwards rate trend absolute relative basis ideally want it above mid april highs but first setup would be hold 720',
#  'well my legs are pretty much shutting off randomly but imma clean',
#  'such broad statement many entry opportunities aapl both key resistances example',
#  'i really like how tend old customers with smoking fresh software updates',
#  'about hit golden cross weekly too even more significant been following this move few weeks bought every dip that found support trend lines',
#  'unfair fully qualify it as system was only 10 billing but solar saved 210 electric that amount time',
#  '1 hour testing again previous high emas are coming rsi overbought higher lows as well buy zone available our premium channel login review discord telegram',
#  '',
#  '',
#  'coms',
#  'don t fight it robert just jump board train there is room enough everyone',
#  'our last 12 swing trades have been winners bbig 793 dlpn 111 hp 86 cost 55 f 45 if you took just contract each trade you could ve made 1 191 our membership is just 13 kplt kura gsat rnxt ry nio amc gme',
#  'my watchlist tomorrow aapl over 154 155c amzn over 3440 3500c googl over 2900 2930c over 740 760c snap over 75 80c snow over 300 310c gs under 409 405p hood under 42 5 40p under 729 720p',
#  'why so you stop loosing money shorting',
#  'if you want some bangers primed get moving off current levels check out hd dpz cost w my top watches next couple weeks everyone favorites roku',
#  'if young investors can buy fractional btc why not i don t get this notion that young investors can t afford invest',
#  'lol yes 4 googl 5 after hours trade',
#  'aapl nvda bynd snap dpz aa',
#  'many killers death by 420 cuts',
#  'fb same 1 3 4 200 next weeks swing 4 3 9 100 amd 2 7 3 7 37 ran around 4 730c 5 75 11 91 holding 1 2 overnight avgo 500 506 upst gap flush couldnt get over 222 key level',
#  'i wonder who tried short got rekt here lmao',
#  'btt x bottom gem spy shop amzn nvda roku ebay amd bb dal dow qqq znga aapl ese spce fcel trip bynd mrna nok oxy ccl cron dgly htz penn gmbl crm gnus ba wkhs flir crex mark eols blu novn abbv azul amc',
#  '10 4 1000 gary',
#  'dive dive dive i havent seen any posts about them recently im guessing its doing well above 700',
#  '',
#  'yup fully agree end month september down month normally but finally cleared resistance made higher high so fingers crossed possible all it wanted was 78 fib level at 735 way back 785 high but hope not hoping slight dip lose 750 pop',
#  'winnings initial investment 494634986 36 64 realized 272 m estimating average buy price 35000 btc with 38 700 btc holdings btcusd',
#  '',
#  'bears be like nio lcid boom bop bing',
#  'lol i told it would rally off this no matter what anyone thinks',
#  'trading ideas strategy tuesday 08 31 2021 free trade via',
#  'gm ceo said feb chip supply concerns not issue production government came out doubled down aug said its easing up no worries bmw vw have said it is longer term concern all along their credit',
#  'besos retired file billion dollor lawsuit musk builds humanoid before retirement amzn',
#  'most mentioned wallstreetbets over last 7 days via',
#  'protect him at al cost',
#  'btc eth sol spy doge this is my favorite collection solanart',
#  'you have evaluate each setup several are no go like stocks making repeated all time highs also algo is dumb that it doesnt factor maybe 5 up most these setups are impossible aapl amzn spot xly dhr info pypl se bll tri',
#  '2 7',
#  '750 tomorrow',
#  'aapl fb amzn 2 ath zm 11',
#  'confirmed 780 2 days',
#  'also started position as it broke 729 90 pivot at near perfect closing range greater volume than any last',
#  'smart investors know that ai was set itself apart other ev makers if other ev makers had better ai they would have announced by their silence means they haven t even though about developing ai 2021 5 yrs behind again f gm',
#  'hes probably gaslighting parts supply chain disruptions chip shortage auto industry is seeing right just getting brake pads filters is problem some oems',
#  'if this out holds it ll be best trades 2021',
#  'uhhhhh',
#  'state art autopilot safety system puts driver direct contact with first responders when necessary',
#  'nasdaq p surged but sentiment us chinese markets turned bearish pypl 3 6 aapl 3 0 idxx 2 8 2 7 dhr 2 5 isrg 2 2 fb 2 2 amzn 2 1 lulu 2 1 regn 2 1',
#  'junkie tweaker scumbag securities fraud says what',
#  '732 billion',
#  'grabbed 735c right before close',
#  '1500 strike calls all',
#  'left looking even better than expected are you aboard elons rocket anon',
#  'if you some pivot levels or darkpool flow data reply with ticker spy roku se amd nvda chwy amzn qqq bbig mmat any',
#  'these are trending stocks zm gsat aapl hood pypl kplt rnxt crsr stne root phec edu zev sonn discb amc bgfv sol cof crwd any irdm docu dq asts sol1 usd atif valn idex',
#  'penn mara fsr opti spy aapl pltr sos srne snap fb coin btbt aal dkng mvis sndl nakd nio gme sunw fubo amd amc coin wkhs riot msft we alerted spce at 19 ran 57 200 gain daily alerts 15 time fee beat that link bio',
#  'are you even current your existing rent papa',
#  '30 aug 2021in playtesla model 3 hit parked car florida while autopilot according cnbc news didnt seem hurt price action check this link',
#  'moooooonnn',
#  'aapl',
#  'its logical take but not like we havent seen momentum investments work long time before gme come mind',
#  'remember trading isnt about winning but about risk management only then you profit which is simply by product money is tool us as traders not goal process above all',
#  'bast discord group apt jakk dynt spv lmnd gnus graf biol novn chfs ayro solo cemi qqq nby clsn chfs mark shlo nio dlpn wkhs carv ba amzn w jagx ino byfc spy boxl aapl ayro bngo phun kodk nflx m penn f',
#  '08 30 2021 448 900 trading school landing page have questions 949 218 4114 todays stocks mrna sprt gme nflx pton domo coin amc upst afrm snow 27 trades 26 wins 1 even results 448 900',
#  'zm',
#  'xtrader trades best trading group out discord zom ktov jakk idex xspa gene nspr uavs mark tlrd gnus rmbl ttnp mvis prty ghsi nkla cphi pdsb acer izea snes mara prpo spaq trvn kodk htbx peix boxl phun spy amzn aapl',
#  'gigafactory texas 30 august 2021 cyber truck model y factory con via',
#  'aapl',
#  'bast group discord apt jakk dynt spv lmnd gnus graf biol novn chfs ayro solo cemi apt nby clsn chfs mark shlo nio dlpn wkhs carv spy solo w jagx ino byfc spy boxl aapl ayro bngo phun kodk',
#  'stocks trending among elite traders 1 zm 2 3 aapl 4 bbig 5 gsat 6 amzn 7 kplt 8 fb 9 pypl 10 afrm join official telegram more frequent updates',
#  'some plays locked swinging',
#  'discord better more executive trading chat room rock uavs cetx dgly vtiq inpx dpw ntec aese useg ayro cgc akrx mark aprn dkng ocgn tops xspa wisa dkng qqq spy amaz aapl er fb bb fl de zm',
#  'no position it would seem like everyone is watching trading i have no intentions trading it anytime soon why i always want enter before most retail is able identify pattern your entries were 716 or 696 last',
#  'ceo was ostensibly unaware that service was lacking but take immediate action based tweet',
#  'i m looking at 750 has minor resistance at 737 25',
#  '3 catalysts 1 model y is making great impression europe 2 ai made it very clear that there no competitors that can compete with 3 recent news gf berlin austin opening up october super bullish',
#  'next stop 750',
#  'he added aapl amzn room along with others that was just him others room called out some fire picks too',
#  'looking like beautiful setup here broke massive level 729 macd cross tied with golden cross 50 ma crossing 200 ma man get your popcorn ready',
#  'mind blowing potential here join us eltp amfe rdgl rnva skyf abwn alkm fusz cype nwbo aryc dbmm gncc fnma cmgo owcp zngy wmih coho mmex uapc amrn',
#  'being bullish makes me that nkla might pick up here too it has high short interest 31 36 could something happen here',
#  'sdc mind blowing potential here join is cbdd igen tptw opti gmpw vism paso enzc gaxy tsnp aept etfm segi brtx ewll vsym dksc twoh tsnp retc spy',
#  'i finally clearing 730 733 zone ah',
#  'btc eth link xtz ada vet knc sxp twtr es jd baba bidu tme spy qqq dis shop amd aapl sq amzn ea sedg ma v ko pypl rcl goog nkla dkng hd roku nflx fb gild vxx msft thanks discord group traders',
#  'how about please',
#  'kodk dow gnus idex boxl baba bbig taop jfk cemi spy shop amzn nvda roku ebay amd bb dal docu alerts before spikes right as big news drops free discord chatroom',
#  'if gaps up tomorow 800 possible this imo',
#  '',
#  'join tomorrow at 9 30am pt 12 30pm et depth discussion tslas along with rivian ipo zm earnings chinese gaming regulations more tweet us your questions q portion stream',
#  'be only company where they continue raise yoy guidance 10 years what happened companies like zm where they admit decreasing yoy demand plummets by 10 is scaling horizontally into different sectors consistently',
#  'inc surprised with q3 result deutsche bank changed rating underperform as inc is trading at over 80 times its book value with trailing pe over 40',
#  'recap friday mon alertidea gamb 8 30 gt 15 rnxt 6 50 gt 16 18 rnxt 10 12 gt 18 avgo 496 500 gt 507 calls dfns irnt 12 gt 18 qqq 270 gt 280 sql 4 40 gt 6 50 ah se 310 gt 330calls gsat void drma 6 gt 5 68 kplt other aapl bctx pdsb timestamped',
#  'real price come out soon follow price targets',
#  'confirmed that close above 715 more importantly 730 looking that 750 target which lines up with april value high',
#  'road 1000 with some pullbacks along way',
#  '750 is inevitable this',
#  'just most active calls hopefully no bought puts aapl or',
#  'pf zm',
#  'only i don t open up my wealthsimple account during hours i made cool 150 off appl alone',
#  'my calls down big even crazier is that my puts are also down they cant both be wrong',
#  '8 31 wl watch list ev crwd 1 43 docu 0 95 zm 1 96 fivn 0 86 tdoc 1 02 nio 0 65 2 66 chpt 1 64',
#  'did it hurt when you bought coffee trans girl',
#  'what your take why otm call leaps got iv crushed so hard call prices it like dropped',
#  'gapper time',
#  'don t so small all i know is that gf berlin gf austin are be huge catalyst cross all time high 900 october is not too far away',
#  '2017 called wants its lies back',
#  'long term is super under valued',
#  '900c exp 16 jun 23 lt r gt total 19 353 240 900c exp 17 mar 23 lt r gt total 10 890 370 900c exp 17 mar 23 total 5 533 780 charts courtesy finviz',
#  '900c exp 17 mar 23 lt r gt total 20 775 345 900c exp 17 mar 23 lt r gt total 41 801 701 900c exp 17 mar 23 lt r gt total 24 730 845 charts courtesy finviz',
#  '815c exp 17 sep 21 lt r gt total 128 416 850c exp 16 sep 22 total 3 300 000 850c exp 16 jun 23 total 5 178 150 charts courtesy finviz',
#  '790c exp 17 sep 21 total 299 016 815c exp 17 sep 21 total 29 500 815c exp 17 sep 21 lt r gt total 75 900 charts courtesy finviz',
#  '790c exp 17 sep 21 lt r gt total 1 172 836 790c exp 17 sep 21 lt r gt total 1 366 836 790c exp 17 sep 21 lt r gt total 551 446 charts courtesy finviz',
#  '790c exp 17 sep 21 lt r gt total 807 836 790c exp 17 sep 21 lt r gt total 1 516 836 790c exp 17 sep 21 lt r gt total 712 836 charts courtesy finviz',
#  '785c exp 17 sep 21 lt r gt total 522 002 790c exp 17 sep 21 lt r gt total 894 836 790c exp 17 sep 21 lt r gt total 984 836 charts courtesy finviz',
#  '785c exp 17 sep 21 lt r gt total 896 055 785c exp 17 sep 21 lt r gt total 740 134 785c exp 17 sep 21 total 251 612 charts courtesy finviz',
#  '780c exp 17 sep 21 total 197 951 785c exp 17 sep 21 lt r gt total 1 003 055 785c exp 17 sep 21 lt r gt total 1 111 075 charts courtesy finviz',
#  '780c exp 17 sep 21 lt r gt total 637 362 780c exp 17 sep 21 lt r gt total 360 892 780c exp 17 sep 21 lt r gt total 970 487 charts courtesy finviz',
#  '775c exp 17 sep 21 total 149 995 780c exp 17 sep 21 lt r gt total 484 612 780c exp 17 sep 21 lt r gt total 788 487 charts courtesy finviz',
#  'its zero but not any reason mentioned so far outlet has round connections power strips all have oval connections',
#  'sometimes car is just off',
#  'how was shorting',
#  'could soar short squeeze technical analysis weekly daily charts august 30 2021',
#  'top gainers glbe 11 56 clir 4 39 2 67 top losers sqqq 3 57 z 3 16 et 2 0 up 0 56',
#  'be patient sure you have comprehensive trading plan before chasing into trades',
#  'most active flow 85 call flow aapl 91 call flow sprt 56 call flow bbig 89 call flow amd 94 call flow',
#  'norway update continuing climb',
#  'leading arkk out triangle',
#  'between arrows used 200dma as incredible support never closing below it macd also curling upwards crossing daily',
#  'crashes into police cruiser self driving cars have learn how drive',
#  'there is 1 company p 500 nasdaq 100 that developed golden cross',
#  'love app s3xyiest car i ever owned excited about future',
#  'long term margin expectations may be bit high',
#  'this is happening large cap rally amzn aapl several more via',
#  'ups downs monday 8 30 top gainers glbe 11 56 clir 4 39 2 67 top losers sqqq 3 57 z 3 16 et 2 0 up 0 56 bought v wsr',
#  'todays top bullish flow aapl fb sprt amd msft',
#  'penn mara fsr opti spy aapl pltr sos srne snap fb coin btbt aal dkng mvis sndl nakd nio gme sunw fubo amd amc coin wkhs riot msft we alerted spce at 19 ran 57 200 gain daily alerts 15 time fee beat that link bio',
#  'derrick pro desks afternoon meeting 8 30 gt coverage includes spy qqq iwm aapl afrm root sklz jets path rblx mgi wmt dis pltr amd',
#  '730 730 860',
#  'buyback announcement would be best indication if beta 10 is really good this probably jump over 4 digits march toward 5 digits',
#  '2 4 above 5 ema prior peaks have occurred at over 7 10 when momentum is strong putting short term too at 764 785',
#  '752 tomorrow if it breaks 739 if it breaks 752 800 is possible before end this is direct reaction powell message friday that asset purchases won t taper rates won t change',
#  '800 is just 8 8 away',
#  'big drop tomorrow morning',
#  'fb',
#  'can you cleat btc confusion real time it appears some people dont understand your stance it thank you',
#  'lets not mess up this 750 tomorrow id be happy',
#  'buy with perfect foresight better 3 words count',
#  'gettin interesting',
#  'i m understanding few words here there but not whole thing but i thought some might find it informative if they understand german full clip german tv show',
#  'robots are good dancers',
#  'why did msft dip bit adding friend',
#  'rinse repeat part 4',
#  'this is only beta with neural net automatic navigational ability',
#  'ohhhhhhhhhhhhh yeah is gonna fuckin',
#  'no more this it stressful',
#  'what happened at that dip right there anyone',
#  'real price come out soon follow price targets',
#  'elon at it again elon musk just made mind blowing breakthrough biggest update yet',
#  'no retired off equity',
#  'how luxurious that looks waiting line parking lot hot car waiting charger good times elon',
#  '',
#  'please join myself twitter space discussion about 2022 outlook potential catalysts tomorrow 11am ct',
#  'rinse repeat part 3',
#  'step it up next time ive been trying 100 10k challenge',
#  'rinse repeat part 2',
#  'tone deaf charlatan who jets around maximize his time roasted lies not giving shit about customers time',
#  'competition is coming killer taking customers away hahahaha',
#  'sprt made it cnbc list sprt can easily be runner tomorrow gme bbig sprt',
#  'yes',
#  'rinse repeat',
#  'taliban car choice toyota don t be like taliban don t buy toyota tm',
#  '',
#  '',
#  'spy 8 31 game plan strong close top balance area 700 730 gap nearly filled 732 daily wkly 2u longs 731 gt 737 745 749 753 shorts 729 gt 725 719 715 710 potential reversal zones 710 715 749 753',
#  '92 79 aapl 38 amrs 19 68 vti 36 nvda 14 mq 4 f mq',
#  'i usually sell 1 2 at 100 or more get rest free ride also depends news if it is buyback i would let it run if just technical bounce i would take profits sooner than later',
#  'inc surprised with q4 result deutsche bank changed rating buy as inc is undervalued given its projected growth',
#  'this is why i consider homelessness index higher it goes worse homelessness be because fed',
#  'started coin at 261 tried pltr but closed small loss tried figs as it was coming out dtl but was extended so closed it flat started towards close at 729 50 stop is tight both coin case they turn around tomorrow',
#  'was up down all finally broke 727 barrier around 345 pm great all out level thanks',
#  'number teslas registered norway was 193 with 0 model 0 model x 49 model 3 144 model y making it total 66580 source',
#  'cool beans tslas cap price are very close right',
#  'cc',
#  'top sweep activity smart money daily recap courtesy real time dashboard 1 aapl 265 6k contracts 2 49 7k 3 bbig 43 4k 4 amd 27 5k 5 f 22 3k',
#  'spoiler it was never was top priority',
#  '1 month free lottery participation allost 2k win small account thanks level guidance that 729 level is free money if you play it well dont give back profit later greed maximize principle minimize greed',
#  'burry deleted his twitter i guess we can declare w here',
#  'amendment im guessing ny rolled over again',
#  '2018 this was all be fixed within 3 6 months',
#  'conti 1 2 bullish stocks 91 07 wkhs 90 46 fsr 90 35 sndl 90 07 cmcsa 90 03 uaa 89 93 ivr 89 77 lac 89 66 dis 88 97 slrx 88 76',
#  'dmyi started at buy with 18 price target at benchmark bill gates michael dell invests pipe ionq other pipe investors hyundai motor company kia corporation msd partner marc benioff time ventures silver lake fidelity amzn msft',
#  'beta420 secured',
#  '',
#  'secrets they dont want you know spy aapl',
#  'tuesday rnxt afrm zm baba',
#  'i m same boat as you placed lr order want tradein my my are you looking sell 3rd party considering doesn t factor fsd value during trade',
#  '8 k filing update with state york doesnt exactly say much',
#  '',
#  'when you stop being shill',
#  '',
#  'much better 750 coming im more interested what happens after',
#  'that be some derrered revenue bottomline q3 or q4 depends when button come available',
#  'check out my latest video india gigafactory coming soon watch',
#  '',
#  'todays experience with never is tomorrows though be amazeballs',
#  'beautiful bull flag breakout move higher if it can take out 731 with move towards 744 750 start it is holding above all 3 emas which is positive indicators are neutral bullish',
#  'yeah i love those stupid comments people who havent even done their homework oh you forgot is be car company forever',
#  'stocks trending among elite traders 1 zm 2 3 bbig 4 aapl 5 amzn 6 hood 7 kplt 8 gsat 9 pypl 10 fb join official telegram more frequent updates',
#  'stocks trending among elite traders 1 bbig 2 3 aapl 4 amzn 5 sprt 6 afrm 7 amd 8 any 9 fb 10 kplt join official telegram more frequent updates',
#  'bbig fbcd wish amc',
#  'fuck mb lfg',
#  'aka no dealer business model',
#  'bbig mmat amc sol',
#  'lets how plays out rest this some 4 6 otm calls might do really nicely here i might already be them',
#  'premature mortality',
#  'patience is what values more than btc',
#  'up 1600 5 years lol',
#  'nearly 3 yrs ago how time flies',
#  'remember last 5 years when kept slashing capex budgets service center growth plans you said you would fix service years ago you failed again',
#  'sq pton as hedge',
#  'trying narrow my focus looking apps pltr my two big future plays behind both early i keep adding',
#  'guess whos getting robotaxis guess who didnt manufacture them',
#  'p500 my pf aapl 3 04 nvda 0 23 2 67',
#  'beautiful bull flag weekly chart f just bought some shares',
#  'locked up supply doesn t asset less volatile daily trading float can actually asset volatility we this many examples such as that can do upwards 20 swings trading float doesn t necessarily reduce volatility or mean price rise',
#  '',
#  'study spy spx es f voo ivv dia dji djia qqq ixic tlt ief tyx tnx btc eth iau gld vix viix uvxy arkk arkw',
#  'jake i did same',
#  'you should absolutely not be concerned this is perfectly normal you are kind politically correct customer that values thank you',
#  '',
#  'profitable crypto btc xrp srm eth sl rsi matic btt bnb tp macd ath kcs skl fil doge lol fud',
#  'imagine amount time autopilot save humanity',
#  'gotcha i thought it was opposite seems like both are yet ground really then lots crazy future deals vale nickel deal almost overthrow caledonia government elon saying nickel might worlds most valuable commodities',
#  'what was that crazy ah dip',
#  'aug 30 2021 my pf 0 72 aapl amzn zm dal spce crwd 34 aapl 9',
#  'maybe that was elon buying after hours',
#  'my pf 0 72 amrs asxc best 2 67 worst amrs 5 55 my pf ge pfe rprx asxc amrs zi xlk soxl',
#  'bringing this up as this would not be widely known it is tslas business model skimp quality service',
#  'clf be short squeeze 54 short interest cyclical peak is over 100 it being manipulated every call date they gme amc lesson doge',
#  'them 750s looking good especially if can that 730 wall',
#  'attn americans free is total lie it 100 rigged',
#  'then beta 11 then beta 12 then another hardware update then beta 14 then another ai then beta 15 enough already it time refund everyone who purchased ap fsd',
#  'aaaand we have golden cross but wheres media golden cross green arrow is when 50dma crosses 200dma upside death cross red arrow is downside',
#  'bch news yes thats huge aht vxit enzc hmbl bb amc gme ada doge coin eth rite btc',
#  'great thread tslas pitch rooftop solar west texas promising replacements hail damage is part package',
#  'btt x by long shot as most searched past 72 hours amc mgm eegi hmbl phil enzc kync ada eth ggii vxit enzc amc gme',
#  'could add as well innit',
#  'hi gary thanks all your great insight just question trading why when is up 20 are long calls down cheers',
#  'nvda ceo elon musk raises red flag about nvidia 40 billion acquisition arm here why',
#  'lcid nio li xpev fsr vwagy',
#  'what attn americans every american should have problem with this',
#  'top 10 holdings end august small adds tcehy amzn otherwise left portfolio alone se climbed top 10 list its own terms msft tcehy nvda baba crwd ttd tsm shop se',
#  'within spec hey',
#  'i love it when i forget check all then 730 91 2 67 yahoo finance',
#  'volume chart animation free super stocks app',
#  'aapl',
#  'chart flow overview 730 level cleared looks like it got more hurdle around 745 area before it can try massive move showtime',
#  'mobile service doesn t help with solar issues papa which is too bad as it seems no helps with solar issues',
#  '',
#  'this was my dooms food if dipped below 500 buy more',
#  'patreon plays bbig calls amd 115 call 220 gt 250 740 call 465 gt 510 aapl 152 5 call 50 gt 200 amc 45 call 280 gt 350 amzn 3600 call 485 gt 800 any shares 6 90 gt 7 45 85 accuracy patreon',
#  'weekly watchlist plays bbig 21 9 45 target hit root 31 quick pump didnt hit 9 60 amc 15 45 target hit amd fubo ma fb 60 all targets met coin etsy 100 all targets met 70 732 target met 60 accuracy this free list',
#  'winnings initial investment 510860057 37 84 realized 272 m estimating average buy price 35000 btc with 38 700 btc holdings btcusd',
#  'only our discord no body does it like us join here aapl amzn spce meli googl twtr fb nio docu rkt fubo shop wmt mcd dis msft amd zm sbux snap ma v ba ccl rcl qs bkng rkt lrcx nnox spy iwm se gs bac baba',
#  'weekly long or short it with btc trade8',
#  'celh',
#  'todays most active puts sprt aapl bbig ual hood',
#  'most bulls believe core why do we diversify if is 10x here we are long',
#  'i started investopedia years ago 2013 when stuff was free got into purely based emotion got lucky optionsplaybook is good place too selfstudy but def helps have experienced people who can explain things when starting out sure',
#  'position looking sweet into this',
#  'sound systems cars are so amazing makes everyday drives so much better',
#  'what are your price predictions 5 10 years',
#  'i definitely hold some but i just try remember it probably won t go up forever keeping my eye this solely as exit timer lol',
#  'thanks bringing this up ive never heard this before who wants cut paste 20 other times this fraudster promised open more service centers because he was unaware waiting times roflmao',
#  'reminder november ath',
#  'is killing it',
#  'i m always fascinated by q elite not taking journalist task are they afraid losing twitter followers these people are disgusting animals',
#  '',
#  'elon musk replied',
#  'what are you watching into tomorrow why im sq dis wday',
#  'vih big shortsqueez kandidat 45 short awesome loww zm mmat ater sonn clov wish aapl amzn rntx',
#  'missed amzn but swinging looking good',
#  'is trying out lfg',
#  'definitely plausible but i don t it as far off as you re betting koenigsegg supercars are testing it w gas volcanoes that far cry mainstream but next decade might adoption there may be too many years dominance baked into price',
#  'inc',
#  'took some 750c overnight after watching it close strong haven t been trading so just swinging long amd lulu sq coin i ll reduce my longs early tomorrow never like being too exposed long when markets r bit overbought',
#  'huge fan by way could i borrow 3k i ll pay it back 12 months when we go 3x',
# ...
#  'moving after hours',
#  'thanks your suggestion btw im software engineer 730 moon baby',
#  'junio del 2019 espero que me hiciera caso esto es antes del split mario le digo que el abuelo no duerme descansa y mi amigo un anti pues que la veremos 1000 post split en en cartera',
#  'ah 737 yellow box shall set you free dont mess this up elon i want 763',
#  'target after 50 fib support held is at 55 50 or 741 00',
#  'key 730 after hours',
#  'zm pton these two were just our public alerts discord our private members played aapl',
#  'lol little willie blocked me stocktwits he couldn t handle truth basher',
#  'todays most active options aapl gsat bbig nvda amd fb edu wish pltr',
#  'been awhile since was top buy flow it about go nuts that close over 730 was all it needed',
#  'move',
#  'talk about unusual options activity sweepcast over 115m bullish side unusual calls some calls hitting 900 850 strikes this looks as its getting ready some major',
#  'lmao gap up 744 by tomorrows open all gas no breaks ah',
#  'wants run',
#  'ah',
#  'pump afterhours',
#  'all them could be td company but i guess reaches first',
#  'if it breaks 731 then it possibly headed 781 resistance',
#  '750',
#  'post recap 08 30 21 video amzn iwm qqq zm',
#  'so whole if passes 730 we get short squeeze was actually not bs',
#  'holding all paid off big at this 730',
#  'my best investment ever up 295 7 what i like most about nvx is they are rare that none their systems rely china which is good usa next thing i like is their board directors im just newby investor up 154 1 since march 2020 mostly',
#  'tlsa closed above 727 key resistance 735 holds 750 773 next major resistance i am holding weekly while added some more 09 17 2021 780c any news this amount call sweep is unusual partnership aapl ev buyback',
#  'nxmh soaking gift price is always fun massive bull trend coming nasdaq uplist tsnp segi nsav ggii wbba fsr bynd migi avvh igex opti sdni dkmr sfor ltnc eegi pfno wdrp eeenf sdni cpsl ftrk',
#  '737 ah any news',
#  'fully support this innovation automated driving can be done safely gradually is simply choosing not',
#  'do you have chart thank you',
#  'closed right this pivot 730 above it tomorrow it begins',
#  'because i don t top until 10 20x here i have time it can go down sure but meantime it could go up 50 100 while i wait top is no where near',
#  'is already run 750 after hours',
#  'i cant wait til i can graduate with you',
#  'top buy flow money 08 30 2021 spy aapl qqq via super stocks app',
#  '212 up bullish reversal with ftfc green',
#  'squeeze ah who blew up',
#  'making its move with some support news glad we caught this',
#  'closing bell 730 91 2 67 join hype list',
#  'not selling single next 10 years as long as keeps executing unless i money which case i try get loans before selling shares i like stonk',
#  'i don t buy lot subscriptions or material things focus family personal health put money primary job into some other stocks i don t use leverage i don t invest what i can afford lose i know what i own i have patience ands sleep well at night',
#  'glad i kept contract overnight',
#  'flying',
#  'someone has some monster good news that is scooping up shares',
#  'closed trades august 30 nice trading i closed some my ttd position up at 114 about 6 gain open positions is acting better aapl is zooming up too',
#  'long here',
#  'gafam aapl fb amzn 3 10',
#  'corriendo despues del cierre',
#  'go crazyyyyy',
#  'what be next trillion dollar company nvda pypl let me know your prediction',
#  'let go',
#  'finished with following sign signifies add potential aos pm jbht nvt slab xm iqv cmg lkq dxcm team lot setups be had plenty add potentials',
#  'hey how is that short position you recommended last month treating ya oh that right you don t invest money you just take payouts failing ice car companies talk shit clown shoes size 15 this guy',
#  'those who neglect acknowledge larger time frames can miss out understanding bigger picture equitys future performance check out weekly breaking out triangle upside with big old bullish macd crossover nvda gme amc aapl qqq',
#  '736',
#  'rocking ah be good tomorrow',
#  'come papa',
#  'is ready growth',
#  'strange activity split incoming',
#  'up over 735 ah wonder if some shorts are closing their position before tomorrows open',
#  'winnings initial investment 524955214 38 89 realized 272 m estimating average buy price 35000 btc with 38 700 btc holdings btcusd',
#  'weekly b o is big deal',
#  '',
#  'how many these hit all them big breakout with strong close tomorrow is most important this months',
#  'be clear this does not mean i go down i own it i am merely saying it is no longer good r r my sys it may very well run but i dont enter call option trades after 2 3 spike just my system my 2 cents',
#  'call was fire keep it up',
#  'close 110m net bullish flow',
#  'glock 08 30 recap bbig 1000 any 250 amd 180 sdc 110 100 atvi 38 lcid 56 gocu 55 dlpn 44 ebay 44 gsat 30 root 40 pltr 13 spy puts like this if y all wanna live trade tm',
#  'with golden cross daily as 50 sma crosses back over 200 sma',
#  'ah horny',
#  'fib master has spoken 780 end',
#  'nflx 2 very nice charts these daily are primed potential',
#  'ps bulls running into close ah',
#  'tagged 735 afterhours oh my this is explode tomorrow',
#  'oh my 734ah',
#  'auph aup fair valuek 63 01 usd after getting phase 3 fda approval ip patent protection 2037 spy qqq iwm vix fb aapl amzn goog msft nio dkng penn mara riot baba sp pltr zm bb mmed amd intc cciv',
#  'open positions buy price gt current price edit 65 19 gt 61 80 amd 106 20 gt 111 32 aapl 149 90 gt 153 12 ntla 157 40 gt 153 95 ttd 79 40 gt 80 71 698 60 gt 730 91 no short positions',
#  'continues move higher after hours fib gp would be lovely tp',
#  'short give me your money',
#  'this awesome tell guy who put this together thank you isnt bidding power infrastructure texas',
#  'i ve gotta confess i was braced pull back as little supply chain fud over weekend but is looking very strong',
#  'companies bucketed saas tech coin nvda shop twlo sq pltr ttd crm ddog apps cloud security net okta crwd zs healthcare smfr gh',
#  'running ah next 745 11 760 7 785 94 811 17',
#  'lfg',
#  'nuts',
#  'lol squeeze away',
#  'probably hits 750 tomorrow',
#  'long weird amount sept 10th 750s since yesterdays close it has only just begun may god forgive them what they are about do',
#  'gets approval four models india testing agencies',
#  'real strong performance by amzn after its gap down july 30th looking fill gap check out macd rsi bullish trend amzn nvda msft aapl spx qqq gme amc',
#  '',
#  'who has two thumbs bought calls',
#  'those after hours though',
#  'bbig taop jfk cemi spy shop amzn nvda roku ebay amd bb dal dow kodk aapl over 75k people join discord group',
#  'car ownership',
#  'lmao at when told me sell at 540 pre split 12 months ago yeah do you know what planet you live motley do you know whats coming next',
#  'thoughts prayers with shorts',
#  'ripping ah',
#  'wonderful start avgo aapl amzn all green trades 780 more complete my i gaps up tomorrow be amazing',
#  'you dont have guts short you know youd lose every penny you have',
#  'off good start also this is second row up friday monday combination',
#  'strongly agreed',
#  'at ah',
#  'haha so true this would be beastly portfolio i reckon with plenty diversification too as they all have different approaches but biggest holding would definitely be',
#  'la conduite autonome chez inclut elle aussi la navigation sur cours d eau',
#  'me is bit dead money here next 50 100 is gonna be harder id just trade it time time',
#  'entered this m at 13 credit fill',
#  'so far so good nvda avgo already printed money up big',
#  'at those lovely monthly candles why do amzn nflx are pumping gotta preserve structure which means theyre not ready crash mkt yet',
#  'tehad shinfi r go55 eadd lasagna sumou',
#  'gsat',
#  'careful i saw someone industry last saying same thing about his friends being long calls that being sure sign top this is july 2020',
#  'is only company that has infrastructure maintain ev charging ports gm ford companies like fisker fsr lucid lcid are light years away anyone that says not dominate this space 7 10 years i believe is incorrect',
#  'trades 740s 8 5 gt 10 holding some as these are next weeks se 340s 4 gt 5 48 etsy 220s 2 00 gt 3 4 pltr 27s 44 gt 78 holding position',
#  'is only beginning stages so many things they are working',
#  'all friends technical analysis golden cross',
#  'go back over 1k soon aal nakd dynt amc gnus uavs jakk novn amzn ayro imrn nak borr ghsi wtrh nakd mark shlo nio hmhc mdly jill gril jagx ino byfc spy boxl aapl ayro bngo',
#  'after 730',
#  'seven poll answers owned during dotcom lots young investors or older investors that don t like polls lol',
#  'it already',
#  '750 coming',
#  '8 31 daily plan 2 2 mvis call gt 15 21 put lt 14 39 frog call gt 39 28 put lt 38 33 val call gt 67 99 put lt 66 05 cake call gt 46 70 put lt 45 33 spy ndx iwm qqq btc eth aapl amc gme cei glbe amd pltr sol root',
#  '8 31 daily plan 1 2 dkng call gt 60 80 put lt 58 66 ba call gt 222 40 put lt 217 53 biib call gt 345 78 put lt 120 43 mara call gt 40 77 put lt 37 65 spy ndx iwm qqq btc eth aapl amc gme bbig any amd afrm fb',
#  'wow 733 50 de 715 0',
#  'bear forecasts august 30 2021 13 15 00 pdt ticker log change intraday ttcf 3 72 iyt 1 26 edu 6 27 qld 1 72 aapl 2 47 gs 1 44 vxx 0 20 v 0 72 zm 3 60 1 70',
#  'closing over 728 744 if we can stay over 728',
#  'thanks gt earn around 9k thanks free vxrt wkhs tril ccxx lca optn blnk ino amzn nkla save vrm tril bbar stng gluu znga aapl bynd mrna nok oxy cron rcl spy penn gmbl crnc rgr xlf wfc spot uber gnus',
#  'spy qqq good evening overnight swing 9 3 740 750 c broke out closed over 730 good luck bulls',
#  'move ah next 735 750 761',
#  '',
#  '',
#  'nice closing heavy volume weekly 750s watch move tomorrow',
#  '1m 0 1 1k 1 10k 10m',
#  'i i am only stupid investor who buys only ahs',
#  'money flowing',
#  'im sure im not only that saw sees this',
#  'tslaaq',
#  'i picked up total 31 shares seem like gift after next split rally onward 1 2 3 trillion cap',
#  'rising price volume daily appearances since 2010 156 close 5 days later avg 2 22 sd 20 70 worst 67 20 best 174 35 10 days later avg 3 19 sd 25 26 worst 164 58 best 120 49 30 days later avg 7 88 sd 54 30 worst 201 26 best 324 64',
#  'todays plays recap amd c lotto swing 1 02 3 4 240 nvda c swing 6 3 13 90 roku c swing 3 3 4 05 22 nflx c swing 3 70 5 25 42 amd c spread swing 0 3 0 65 120 amd c dt 2 00 1 70 15 abnb c dt 2 00 2 6 30 c dt 2 3 2 52 10',
#  'levels provided by fb aapl have been spot',
#  'great move closing at high moving after hours gapper tomorrow',
#  'most traded contracts aapl 3 september 155 call aapl 3 september 153 call 3 september 750 call aapl 3 september 150 call aapl 10 september 155 call gsat october 3 call aapl 3 september 150 put bbig september 8 call',
#  'performance some fellow traders our community calculated risk great analysis regular alerts spy shop amzn nvda roku ebay bb dal gme qqq aapl ese spce fcel bynd mrna nok oxy cron dgly penn gmbl crm ba wkhs nio twtr',
#  'forming golden cross daily',
#  'looks gorgeous this',
#  'what happens with when options are closed it does what it should you can witness that ahs as it cant be manipulated like during hours',
#  'after 730 algo are here us this time',
#  'was mixed gain loss but glad that many if not all our group were gain side aapl nio spy wmt fb pt pton gme mvis baba ath crm blnk gme amc amd adbe riot vxx uvxy sqqq xom fubo pltr qqq oxy chwy bbig',
#  'we have golden cross daily should open wider tomorrow we also have some ah action first time awhile',
#  'sprt 1st carbon neutral bitcoin mining us lot people do not know that this epic squeeze has todo with catalyst that solves concerns about increase use fossil mining',
#  'buying doge eth',
#  'everyone goes about teslas driving themselves because they are driving themselves under supervision people dont go about fords driving themselves because fords suck at it they cant negotiate slight curve highway some pumping mooon',
#  'closed above resist first time while',
#  'we alerted 250c 10 scaling check watchlist idea ozsc tlss vyst bbrw gaxy tops tptw opti pctl aapl cctl cts htbx boxl msft abml etrf nak pmcb brtxq htbx tril nio nkla sthc atds gnus rnwf tsoi esyl hemp alyi',
#  'is doing great so far after hours hopefully we hit 750 range soon',
#  'started trades knbe abnb partial how about you',
#  'all hydrogens explode ah w this bank america nyse bac compared hydrogen smartphone pre 2007 or internet just before dot com boom boom plug fcel bldp nkla nio aapl msft amzn goog fb xom spy',
#  'runner 750c',
#  'jumped like whole dollar this minute',
#  'he knows that itself is really only worth half that',
#  'i team takes guesswork out trading helps you take your trading strategy next level ayro nkla save vrm shop bbar znga aal cacc ese spce fcel trip bynd mrna oxy penn gmbl spy ktov gnus ba fcel',
#  'penn mara fsr opti spy aapl pltr hood snap fb btbt coin gme aal dkng mvis sndl spce mara nakd nio sunw fubo amc coin amd msft wkhs we alerted novn at 50 ran 1 30 160 gain daily alerts 15 time fee beat that link bio',
#  'pushing up ah wow',
#  '750 tomorrow',
#  'my mind lt 3',
#  'based various chip makers shortage chips which directly restrains car production not disappear overnight us auto inventories have fallen lowest level record',
#  'gaining momentum price action last month screams accumulation me dips bought outperforming others ev space there is not insignificant probability catch up rally near term 780 next stop then ath if momentum continues i m buying high or low',
#  'like legit traders include this chat making profits free check out nvax tvix nvax uvxy wfc gsk mmm tot amd bud fis hdb c rtx un spgi ba td blk intu bti mdlz cat bhp sunw sqqq pola nkla nete',
#  '30th august 2021 awakens',
#  'building brick by brick our analysts motto pay visit our community cgm apt jakk dynt spv lmnd gnus graf biol novn chfs ayro solo cemi nby clsn chfs mark shlo nio dlpn wkhs carv spy amzn w cgc ino byfc aapl mara bngo abus',
#  'sir isnt auto company',
#  'volumes aapl 2 2m 78 call 23 put 1 2m 70 call 30 put bbig 772k 86 call 15 put amc 767k 74 call 26 put amd 554k 79 call 21 put pltr 535k 80 call 20 put nvda 466k 64 call 36 put gsat 429k 91 call 9 put',
#  'closed at its highest level since april 27th while its 50 sma simple moving average formed golden cross as it pushed above its 200 sma technically quite encouraging',
#  'is 2022 be 2020 deja vu join myself tomorrow here deep dive with into his catalysts more',
#  'gafamant gafam amd nvda',
#  'amzn running premarket news article out sgma jfin nvtr nndm dmpi ter manh emma cnat acst snap home thc amd cgc cron tlry hexo ctrm',
#  'bear forecasts august 30 2021 13 13 00 pdt ticker log change intraday ttcf 4 51 iyt 1 26 estc 2 55 edu 6 72 qld 1 73 aapl 2 51 gs 1 44 vxx 0 20 1 62 zm 2 00',
#  '730 p sold last 5 mins',
#  'bull forecasts august 30 2021 13 13 00 pdt ticker log change intraday 1 62 aal 3 43 wkhs 0 61 nvax 3 95 rkt 1 03 docu 0 42 tqqq 2 40 afrm 1 73 aapl 2 51 bntx 0 94',
#  'looking interesting again as short term play not long term bull this',
#  'almost 6b call flow i ve never seen so many golden sweeps my life insane',
#  'unusual options activity aapl gsat wkey sdc bbig aso luv didi root aeo fb wday nvda clov khc dash wfc hood hofv amzn wfc',
#  'i missed entry above 715 run towards 725 i was waiting this bounce i missed it when it happened congrats if anybody capitalized also swing entry 653 58 is doing awesome congrats if anybody riding it i have closed it already',
#  'this should be nice tomorrow 750c',
#  'always slow steady you know i only took play i was just helping so many people okay i took spy spx but they were short ones bc i had been waiting amzn month i did grab min but i was too focused behemoth lol',
#  'todays most active options aapl 2 277k 22 put 78 call 1 146k 30 put 70 call bbig 787k 14 put 86 call amc 784k 26 put 74 call amd 568k 21 put 79 call pltr 538k 20 put 80 call nvda 476k 36 put 64 call gsat 438k 9 put 91 call',
#  'trading ideas 777 free trade via',
#  ...]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in res:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
