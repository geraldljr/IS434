# %% [markdown]
# In this lab, we will use 'twarc' Python package to interact with Twitter API v2.
#
# We will use Search Tweets --> Recent search (endpoint)
#
# This API endpoint:
# - (By default) Retrieves 10 tweets in the recent 7 days
# - (By setting max_results to 100) Can retrieve up to 100 tweets per API request
#
# Ref: https://twarc-project.readthedocs.io/en/latest/api/client2/#twarc.client2.Twarc2.search_recent
#
# Ref: https://www.youtube.com/watch?v=guHH51GDDI0
#
# Ref: https://catriscode.com/2021/05/01/tweets-cleaning-with-python/

# %%
import plotly.graph_objects as go
from twarc import Twarc2

# %%
# Paste in your own bearer token below
client = Twarc2(
    bearer_token = 'AAAAAAAAAAAAAAAAAAAAAAIdYQEAAAAAreZGogaOpJ4grVjVB0He1ZNS4uI%3DHZQ6oofjV0daUPCAPScqydAdnEl5LTkIFrWuxZxYRwYpv8FdM9'
)

# %%
query = 'covid lang=en'

# %%
results = client.search_recent(
    query=query,
    max_results=100,
    tweet_fields="author_id,context_annotations"
)

# %%
for page in results:
    print("======================")
    print(page)
    data = page['data']
# Out:
# ======================
# {'data': [{'author_id': '1944331154', 'id': '1487788761215815682', 'text': 'Dr Dinah Parums. Publications on COVID-19. World Health Organisation (WHO) Publication Resource. 2021/2022. https://t.co/P4XLu4PIB5', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '298689306', 'id': '1487768160916885507', 'attachments': {'media_keys': ['3_1487768159830609920']}, 'text': 'The Saudi Ministry of Health announced the registration of 3,669 new infections with the Coronavirus (Covid-19) pandemic and three deaths, during the past 24 hours. #QNA\nhttps://t.co/pmr8YMPmAi https://t.co/b8szNeVE1Y', 'context_annotations': [{'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '1156189365351022592', 'name': 'Saudi Arabia Ministry of Health (وزارة الصحة السعودية)'}}, {'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'entities': {'mentions': [{'start': 0, 'end': 12, 'username': 'labella1503', 'id': '356676553'}, {'start': 13, 'end': 24, 'username': 'beffi_sk8s', 'id': '1447525062525992960'}, {'start': 25, 'end': 33, 'username': 'lea4711', 'id': '1224403383609708544'}, {'start': 34, 'end': 44, 'username': 'Orienskii', 'id': '1349472889679048705'}, {'start': 45, 'end': 57, 'username': 'wenig_worte', 'id': '28804762'}]}, 'author_id': '1346988213630599168', 'in_reply_to_user_id': '356676553', 'id': '1487756212976377862', 'referenced_tweets': [{'type': 'replied_to', 'id': '1487722882478362626'}], 'text': '@labella1503 @beffi_sk8s @lea4711 @Orienskii @wenig_worte https://t.co/njT5D8U2uE\nNur eine von vielen.\nWas haben Sie für eine Ausbildung?\nWenn sie jetzt nicht gerade Medizin oder Pharmazie studieren oder studiert haben, sollten Sie sich zu solchen Themenkreisen vielleicht nicht weiter äußern.\nUnd wieso "kann" es keine Studien geben?'}, {'author_id': '298689306', 'id': '1487753651846275072', 'attachments': {'media_keys': ['3_1487753650592268291']}, 'text': 'The designated authorities referred 770 people to the prosecution for non-compliance with the preventive and precautionary measures in place in the country to contain the spread of coronavirus (COVID-19). #QNA\nhttps://t.co/AM5X81hmkU https://t.co/WKyqhuOuiS', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'ILOAsiaPacific', 'id': '704940912661635072'}]}, 'author_id': '788977883339370496', 'id': '1487692102054162434', 'referenced_tweets': [{'type': 'retweeted', 'id': '1487433606192635908'}], 'text': 'RT @ILOAsiaPacific: The military takeover and COVID-19 pandemic have left millions of workers in #Myanmar in a grim situation. \n\nShould thi…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'entities': {'mentions': [{'start': 3, 'end': 11, 'username': 'xyntrus', 'id': '1341560940593106945'}]}, 'author_id': '1481383932293644289', 'id': '1487600932384755712', 'referenced_tweets': [{'type': 'retweeted', 'id': '1484262167780151299'}], 'text': 'RT @xyntrus: La ORGANIZACIÓN MUNDIAL DE LA SALUD acaba de difundir en su sitio web, el artículo científico que se refiere a la poderosa efi…'}, {'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'helpmefindchuu', 'id': '2875025960'}, {'start': 20, 'end': 36, 'username': 'Irudakedetsurai', 'id': '311872729'}]}, 'author_id': '4187258594', 'id': '1487578099130662912', 'referenced_tweets': [{'type': 'retweeted', 'id': '148003325808347545 ...
# ======================
# {'data': [{'text': "The Ministry of Public Health announced the updated lists of countries' classification based on severity of the Covid-19 pandemic, as part of the travel and return policy for the State of Qatar. #QNA https://t.co/NJTjBbyGRO", 'id': '1486664855704719362', 'author_id': '298689306', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'text': 'The designated authorities referred 653 people to the prosecution for non-compliance with the preventive and precautionary measures in place in the country to contain the spread of Coronavirus (COVID-19). #QNA \nhttps://t.co/XhCZlXzxKr', 'id': '1486664554742431745', 'author_id': '298689306', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486663802217185283', 'author_id': '2583916282', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'text': 'The Saudi Ministry of Health reported 4738 new COVID-19 cases and two deaths. #QNA https://t.co/PJg8E3LVm0 https://t.co/M5dZDzPwsM', 'id': '1486656812757798914', 'author_id': '298689306', 'context_annotations': [{'domain': {'id': '88', 'name': 'Political Body', 'description': 'A section of a government, like The Supreme Court'}, 'entity': {'id': '1156189365351022592', 'name': 'Saudi Arabia Ministry of Health (وزارة الصحة السعودية)'}}, {'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'attachments': {'media_keys': ['3_1486656811088367624']}}, {'text': 'Germany set a new record for the number of COVID-19 infections, two years since the first case of the virus was discovered. #QNA https://t.co/YiTFu3bo67 https://t.co/7fokadHMPH', 'id': '1486654286289383426', 'author_id': '298689306', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'attachments': {'media_keys': ['3_1486654285152727040']}}, {'text': "RT @CurrentNews_EN: China firm on 'zero COVID' policy amid health care system concerns https://t.co/fQaepYWKhh", 'id': '1486651365522870273', 'author_id': '860805278606004224', 'entities': {'mentions': [{'start': 3, 'end': 18, 'username': 'CurrentNews_EN', 'id': '722351221256888320'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'referenced_tweets': [{'type': 'retweeted', 'id': '1486632603600007171'}]}, {'text': 'Coronavirus - Zambia: COVID-19 Statistics Daily Status Update (27 January 2022) @ZMPublicHealth @mohzambia #Africa #Zambia #Coronavirus #COVID19 #Health #Pandemic #Vaccination #BoosterVaccination #InfectiousDisease\nRead more: https://t.co/H6pouo69gB https://t.co/lQAN85Cy6Y', 'id': '1486650894359965697', 'author_id': '255925055', 'entities': {'mentions': [{'start': 80, 'end': 95, 'username': 'ZMPublicHealth', 'id': '952834250797088769'}, {'start': 96, 'end': 106, 'username': 'mohzambia', 'id': '1200316338'}]}, 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': ...
# ======================
# {'data': [{'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486451282269384722', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1389344211238072321'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486451071627272195', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '192322223'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486450966694088712', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '33183740'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486450892589125635', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '68256895'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486450610635431944', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1321883651039207425'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486450509007441922', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '4252288281'}, {'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'id': '1486450410076389377', 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220 ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '785154746818633728', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486384521226473484', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1264640559345471488', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486383123344543751', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '2562014660', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486382273888980993', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1351113039647563779', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486382024646660103', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1223600300126240768', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486381591320571915', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '3305854071', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486380689503178752', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '2233963072', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486380 ...
# ======================
# {'data': [{'author_id': '791644933', 'id': '1486309543533551619', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '417365324', 'id': '1486308410144567298', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '4537015863', 'id': '1486307828461719553', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '874102026132639744', 'id': '1486307723012898820', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '88251779', 'id': '1486307652477108231', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '3060505058', 'id': '1486307161596641284', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}]}, {'author_id': '272351801', 'id': '1486306260756672513', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}], 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'enti ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1923178369', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486270357153751049', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1463568349242212361', 'text': '🤔"Will I be able to land my first job?" Philippines\' university student Raymond asks himself as graduation day nears. He worries that he hasn’t gained in-demand skills. #COVID has only aggravated this, but #SkillsforProsperity is tackling the issue. https://t.co/sr9ajV3ka5 #SDG4', 'id': '1486269376248569862'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '741677155214561280', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486269066893574149', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1186021935534215172', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486268086034571267', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '1199731875947962373', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486266991283429383', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '53889094', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486266701922680834', 'referenced_tweets': [{'type': 'retweeted', 'id': '1486253804270010372'}]}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'author_id': '2244721547', 'entities': {'mentions': [{'start': 3, 'end': 14, 'username': 'chrischirp', 'id': '84035041'}]}, 'text': 'RT @chrischirp: French academy of medicine urges vaccination of 5 to 11s in strongest terms highlighting safety and efficacy of vaccine and…', 'id': '1486266167081811968', 'referenced_tweets' ...
# ======================
# {'data': [{'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'MOPH reported 2,124 new confirmed cases of COVID-19 among community and 427 among travelers. MOPH recorded 4,018 recoveries from virus during past 24 hours bringing total number of cases recovered to 293,182. MOPH announced one new death was recorded. #QNA\nhttps://t.co/4EF9rwKhjr https://t.co/tDSAQxozPd', 'attachments': {'media_keys': ['3_1486026255845707777']}, 'id': '1486026257770950660', 'author_id': '298689306'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @Right2CityGP: 📗 How SSE initiatives contribute to achieving the SDGs in the post-Covid context \n\n🙌🏼Diverse and inclusive economies are…', 'id': '1486002299851923468', 'entities': {'mentions': [{'start': 3, 'end': 16, 'username': 'Right2CityGP', 'id': '3119820711'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1485890797740478464'}], 'author_id': '189546355'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @CODESRIA: 📣Call for Papers for Special Issue\nOn COVID-19 and Its Effects and Implications to African Economies.\nLike and share!\n👉https:…', 'id': '1485999062843285512', 'entities': {'mentions': [{'start': 3, 'end': 12, 'username': 'CODESRIA', 'id': '91147768'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1479063547204280322'}], 'author_id': '167835170'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'RT @Right2CityGP: 📗 How SSE initiatives contribute to achieving the SDGs in the post-Covid context \n\n🙌🏼Diverse and inclusive economies are…', 'id': '1485983520577183745', 'entities': {'mentions': [{'start': 3, 'end': 16, 'username': 'Right2CityGP', 'id': '3119820711'}]}, 'referenced_tweets': [{'type': 'retweeted', 'id': '1485890797740478464'}], 'author_id': '189364634'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '@aboutanurse Maar ja, zoals je zegt, jij ziet het niet.\n\nIk wel, zeker als ik probeer vanuit ogen van een Covid patient zijn woorden te lezen.\nOok zonder IC is herstel van Covid patienten te lang. en dan worden je klachten zo belachalijk gemaakt. Het is maar niks, doe niet overdreven etz.', 'id': '1485959854002999305', 'in_reply_to_user_id': '2354429784', 'entities': {'mentions': [{'start': 0, 'end': 12, 'username': 'aboutanurse', 'id': '248155425'}]}, 'referenced_tweets': [{'type': 'replied_to', 'id': '1485959248790102017'}], 'author_id': '2354429784'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': 'i-manager’s Articles are now Available in World Health Organization : COVID-19 - Global literature on corona virus disease\n\nhttps://t.co/SZF9SQnKZh\n\nhttps://t.co/tBHPYn6w8z https://t.co/Uhb85COPJm', 'attachments': {'media_keys': ['3_1485926157409468424', '3_1485926157396897798']}, 'id': '1485926168163676163', 'author_id': '177883773'}, {'context_annotations': [{'domain': {'id': '123', 'name': 'Ongoing News Story', 'description': "Ongoing News Stories like 'Brexit'"}, 'entity': {'id': '1220701888179359745', 'name': 'COVID-19'}}], 'text': '📗 How SSE initiatives contribute to achieving the SDGs in the post-Covid context \n\n🙌🏼Diverse a ...

# %%
len(data)
# Out:
# 54

# %%
# Convert JSON into Pandas data frame

import pandas as pd

df = pd.json_normalize(data)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   context_annotations     48 non-null     object
#  1   text                    54 non-null     object
#  2   id                      54 non-null     object
#  3   author_id               54 non-null     object
#  4   attachments.media_keys  11 non-null     object
#  5   referenced_tweets       35 non-null     object
#  6   entities.mentions       38 non-null     object
#  7   in_reply_to_user_id     7 non-null      object
# dtypes: object(8)
# memory usage: 3.5+ KB

# %%
# Let's retrieve just the text from each tweet
# Store each tweet text as a List item

tweet_text_list = df['text'].tolist()

tweet_text_list
# Out:
# ['RT @NewszNow: No funds came from #PMCaresFund for #COVID19 #vaccine development, says #Union govt in reply to #RTI query\n\nhttps://t.co/7PZX…',
#  'RT @xyntrus: La ORGANIZACIÓN MUNDIAL DE LA SALUD acaba de difundir en su sitio web, el artículo científico que se refiere a la poderosa efi…',
#  'La ORGANIZACIÓN MUNDIAL DE LA SALUD acaba de difundir en su sitio web, el artículo científico que se refiere a la poderosa eficacia del principio activo de Xyntrus. #virus #COVID #Corona #SARSCoV2 \n\nhttps://t.co/PX3nyMasHj https://t.co/ACnIjAUS7T',
#  'Ministry of Health of Kuwait reported 4,510 people tested positive for Coronavirus (COVID-19) and two deaths in the past 24 hours. #QNA\nhttps://t.co/szYvRbU3ur https://t.co/icYlS6gsGO',
#  'Make sure to check out the COVID Care Program if you are a resident that has been exposed to COVID-19 or who is COVID-19 positive. \n\nClick this link to fill out a survey: https://t.co/ojwLVzI9Uc https://t.co/Fol24xZjob',
#  'Les comparto este video sobre el último trabajo publicado en @Ilo x @PabloArellanoO, sobre la respuesta de los mecanismos de resolución de conflictos laborales ante la pandemia del COVID-19.\n\nSaludos!!\n\nhttps://t.co/tm74AMPz3o\n\nVer el trabajo publicado 👉🏽 https://t.co/NHkR6C5MsA',
#  'RT @cint: https://t.co/c1SEvisJbW\n#Dutch #covid19 January 20 #interactive #Dashboard\n\nPositive #cases:  +39920 (3.720.816)\nIn #Hospital, NI…',
#  '@Ahnenforscher2 If you are referring to the case hospitalization rate of Covid positives here it is by age and sex\n\nDivide everything by 3 and you get the approximate infection hospitalization rates, including the dark figure. In children the dark figure is bigger.\n\nhttps://t.co/t7LJdvI1tC https://t.co/NIU9y7pR7g',
#  'RT @NewszNow: No funds came from #PMCaresFund for #COVID19 #vaccine development, says #Union govt in reply to #RTI query\n\nhttps://t.co/7PZX…',
#  'RT @cint: https://t.co/c1SEvisJbW\n#Dutch #covid19 January 20 #interactive #Dashboard\n\nPositive #cases:  +39920 (3.720.816)\nIn #Hospital, NI…',
#  'https://t.co/c1SEvisJbW\n#Dutch #covid19 January 20 #interactive #Dashboard\n\nPositive #cases:  +39920 (3.720.816)\nIn #Hospital, NICE from 12:00 AM: +24 (78.574)\n#Deaths: +10 (21.188)\nYou can select #data by city\n#Netherlands #Vaccin #Lockdown #corona #BoosterJab #StaySafe #Omicron https://t.co/tjSAxeuE3Z',
#  'RT @RIPESStwit: #RIPESSaroundtheWorld #WeAreSSE \n\n🚀🚀🚀How SSE initiatives concretely contribute to achieving the SDGs around the world in th…',
#  'The UAE Ministry of Health reports 2,902 new COVID-19 cases and 2 deaths. #QNA https://t.co/9aogNtSlBe',
#  'RT @ctisus: COVID-19 findings in chest computed tomography\nhttps://t.co/KNp36jN7yD https://t.co/1EojtC3xJO',
#  'The Saudi Ministry of Health reports 5928 new COVID-19 cases and two deaths. #QNA https://t.co/Uga2N12gPS https://t.co/nySwxI2YW2',
#  'RT @ctisus: COVID-19 findings in chest computed tomography\nhttps://t.co/KNp36jN7yD https://t.co/1EojtC3xJO',
#  'Covid Expansion of Permit for Employees to Work Overtime https://t.co/V4IsR7sYtM | by @BarneaLawFirm?lang=en',
#  'RT @EPSUnions: 4⃣The pandemic demonstrates how public health and care systems are vital in overcoming such a crisis.\n\nBut what will happen…',
#  'RT @IsabelOrtizUN: See our new @ilo paper on @IMFNews #austerity with @RazaviShahra @devikadutt @faduranvv @HelmutSchw \n\n"Social policy adv…',
#  'RT @IsabelOrtizUN: See our new @ilo paper on @IMFNews #austerity with @RazaviShahra @devikadutt @faduranvv @HelmutSchw \n\n"Social policy adv…']

# %%
'''
1) Lowercasing all the letters

This step is important to make sure that all your letters are in uniform.

temp = tweet.lower()
temp
'''
# Out:
# '\n1) Lowercasing all the letters\n\nThis step is important to make sure that all your letters are in uniform.\n\ntemp = tweet.lower()\ntemp\n'

# %%
'''
2) Removing hashtags and mentions

Hashtags and mentions are common in tweets.
There are cases where you want to remove them so you only get the 
clean content of a tweet without all these elements.

You can remove these hashtags and mentions using regex.

import re

temp = re.sub("@[A-Za-z0-9_]+","", temp)
temp = re.sub("#[A-Za-z0-9_]+","", temp)
temp
'''

# %%
'''
3) Removing links

Links are usually not necessary for text processing, so it’s
better to remove them from your text.

temp = re.sub(r"http\S+", "", temp)
temp = re.sub(r"www.\S+", "", temp)
temp
'''

# %%
'''
4) Removing punctuations

Depending on your needs, you may not need punctuations such as
period, comma, exclamation mark, question mark, etc.

temp = re.sub('[()!?]', ' ', temp)
temp = re.sub('\[.*?\]',' ', temp)
temp
'''

# %%
'''
5) Filtering non-alphanumeric characters

The previous step may have removed the punctuations, including all the
non-alphanumeric characters, but just to be sure, we can remove all letters
except the alphabets (a-z) and numbers (0-9). The sign ^ below means except.

temp = re.sub("[^a-z0-9]"," ", temp)
temp
'''

# %%
'''
6) Tokenization

In tokenization, you basically tokenize your text into tokens.

And what is a token? In this case, you split your text into smaller components,
for example a paragraph into a list of sentences, or a sentence into a list of words.

Library such as nltk provides functions such as word_tokenize() or sent_tokenize()
to help you with this.

However, if you just want a simple tokenizing step where you split your text 
into words into a list, then you can do it as simple as the following code.

The result will give you a list of words from your text.

temp = temp.split()
temp
'''

# %%
'''
7) Stop words removal

Stop words are words that are considered unimportant to the meaning of a text.
These words may seem important to us, humans, but to machine these words may be
considered nuisance to the processing steps.

It’s also important to keep in mind that stop words are largely language-dependent.
In English, you have stop words such as for, to, and, or, in, out, etc.

Here I first defined a list of stop words in English.
Then, I match each token with each stop word.

If a token isn’t found in the list of stop words, the token gets saved,
otherwise it’s not saved. In the end, you join all the words into one text again.


stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]
 
temp = [w for w in temp if not w in stopwords]
temp = " ".join(word for word in temp)
'''

# %%
'''
Text Preprocessing: From Start to Finish

I hope you understand the steps I have explained above.
Now we can combine all those lines of code into one function that we can
call and pass an argument to.

The function then returns a clean text that is ready for you to work with.

Keep in mind that the order of steps here are not absolute.
You can arrange them around depending on your text and your needs.
The code below is what I found to be the most effective on the data I
usually work with, but in case you find another pattern of data,
you can always work them out differently.
'''
import numpy as np
import re

stopwords = ["for", "on", "an", "a", "of", "and", "in", "the", "to", "from"]

def clean_tweet(tweet):
    if type(tweet) == np.float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions in english
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('\[.*?\]',' ', temp)
    temp = re.sub("[^a-z0-9]"," ", temp)
    temp = temp.split()
    temp = [w for w in temp if not w in stopwords]
    temp = " ".join(word for word in temp)
    return temp

# %%
tweets = ["Get ready for #NatGeoEarthDay! Join us on 4/21 for an evening of music and celebration, exploration and inspiration https://on.natgeo.com/3t0wzQy.",
"Coral in the shallows of Aitutaki Lagoon, Cook Islands, Polynesia https://on.natgeo.com/3gkgq4Z",
"Don't miss our @reddit AMA with author and climber Mark Synnott who will be answering your questions about his historic journey to the North Face of Everest TODAY at 12:00pm ET! Start submitting your questions here: https://on.natgeo.com/3ddSkHk @DuttonBooks"]
 
results = [clean_tweet(tw) for tw in tweets]
results
# Out:
# ['get ready join us 4 21 evening music celebration exploration inspiration',
#  'coral shallows aitutaki lagoon cook islands polynesia',
#  'dont miss our ama with author climber mark synnott who will be answering your questions about his historic journey north face everest today at 12 00pm et start submitting your questions here']

# %%
# Let's go and apply this to our own tweets
my_results = [clean_tweet(tw) for tw in tweet_text_list]
my_results
# Out:
# ['rt no funds came development says govt reply query',
#  'rt la organizaci n mundial de la salud acaba de difundir en su sitio web el art culo cient fico que se refiere la poderosa efi',
#  'la organizaci n mundial de la salud acaba de difundir en su sitio web el art culo cient fico que se refiere la poderosa eficacia del principio activo de xyntrus',
#  'ministry health kuwait reported 4 510 people tested positive coronavirus covid 19 two deaths past 24 hours',
#  'make sure check out covid care program if you are resident that has been exposed covid 19 or who is covid 19 positive click this link fill out survey',
#  'les comparto este video sobre el ltimo trabajo publicado en x sobre la respuesta de los mecanismos de resoluci n de conflictos laborales ante la pandemia del covid 19 saludos ver el trabajo publicado',
#  'rt january 20 positive 39920 3 720 816 ni',
#  'if you are referring case hospitalization rate covid positives here it is by age sex divide everything by 3 you get approximate infection hospitalization rates including dark figure children dark figure is bigger',
#  'rt no funds came development says govt reply query',
#  'rt january 20 positive 39920 3 720 816 ni',
#  'january 20 positive 39920 3 720 816 nice 12 00 am 24 78 574 10 21 188 you can select by city',
#  'rt how sse initiatives concretely contribute achieving sdgs around world th',
#  'rt pharmacy professionals are key part health care team they have demonstrated that many times over during covid 19 l',
#  'rt pharmacy professionals are key part health care team they have demonstrated that many times over during covid 19 l',
#  'rt pharmacy professionals are key part health care team they have demonstrated that many times over during covid 19 l',
#  'pharmacy professionals are key part health care team they have demonstrated that many times over during covid 19 lets start treating them like it when it comes funding their services national call action',
#  'rt moph statement latest developments covid 19 state qatar',
#  'uae ministry health reports 3 014 new covid 19 cases 4 deaths',
#  'rt pharmacies are facing staff shortages across canada two years being open accessible during covid 19 has taken toll',
#  'saudi ministry health reported 5591 new covid 19 cases two deaths',
#  'moph statement latest developments covid 19 state qatar',
#  'rt no funds came development says govt reply query',
#  'rt thankful this article ongoing covid 19 memorial crack hourglass proiect is',
#  'who africa covid 19 online press briefing read more',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'rt no funds came development says govt reply query',
#  'de sterfte door covid 19 is alleen slechts een veelvoud van de sterfte na dus niet door een coronavaccin je weet inmiddels wel dat de hoax van experimentele gentherapie al lang en breed is gedebunked toch',
#  'rt sailing biking or hiking however you enjoy greece enjoy it carefree with our free middle seat option flight changes fre',
#  'no funds came development says govt reply query',
#  'rt vaccines are safe effective this is cherry picking',
#  'yesterday eurostat updated total mortality files poland last 6 weeks 2021t49 13 701 2021t50 13 722 2021t51 13 618 2021t52 13 107 2022t01 11 319 2022t02 9 733 average mortality poland per week prior covid was 7 7 k',
#  'rt thankful this article ongoing covid 19 memorial crack hourglass proiect is',
#  'rt thankful this article ongoing covid 19 memorial crack hourglass proiect is',
#  'thankful this article ongoing covid 19 memorial crack hourglass proiect is currentlv view at brooklyn museum at',
#  'so youre correctly against establishment re covid but will happily spew that same establishments coming war china propaganda',
#  'rt pharmacies are facing staff shortages across canada two years being open accessible during covid 19 has taken toll',
#  'rt vaccines are available children 5 12 years old search your nearest vaccines centre near merrylands',
#  'rt economic recovery may not be enough repair damage labour markets 19 addressing disconnect between gd',
#  'rt 4 pandemic demonstrates how public health care systems are vital overcoming such crisis but what will happen',
#  'pharmacies are facing staff shortages across canada two years being open accessible during covid 19 has taken toll as we now deal with impact omicron national call action',
#  'rt issue paper covid 19 fundamental principles rights at work via',
#  'issue paper covid 19 fundamental principles rights at work via',
#  'ministry health kuwait reported 4 337 people tested positive coronavirus covid 19 one death past 24 hours',
#  'again influenza 10 year average per cdc kills more kids than covid has rsv kills 500 kills year here i posted data flu disappeared globally everywhere last year whether there were mitigations or not viral interference is thing',
#  'police college will celebrate thursday graduation fourth batch 91 candidates amid covid 19 precautionary preventive measures',
#  'la oms ha recogido en su web una de mis ltimas investigaciones pandemic natives preschoolers remote learning during covid 19 confinement',
#  'rt january 19 with smart graph version 2 3 positive 38200',
#  'rt january 19 with smart graph version 2 3 positive 38200',
#  'rt january 19 with smart graph version 2 3 positive 38200',
#  'january 19 with smart graph version 2 3 positive 38200 3 680 896 nice 12 00 am 19 78 430 10 21 178',
#  'whats new free covid test kits',
#  'moph statement latest developments covid 19 state qatar',
#  'rt europe there is positive correlation between dose uptake amp excess all cause mortality young males higher propo',
#  'rt see our new paper with social policy adv',
#  'designated authorities referred 354 people prosecution non compliance with preventive precautionary measures place country contain spread coronavirus covid 19',
#  'uae ministry health reports 2 902 new covid 19 cases 2 deaths',
#  'rt covid 19 findings chest computed tomography',
#  'saudi ministry health reports 5928 new covid 19 cases two deaths',
#  'rt covid 19 findings chest computed tomography',
#  'covid expansion permit employees work overtime by lang en',
#  'rt 4 pandemic demonstrates how public health care systems are vital overcoming such crisis but what will happen',
#  'rt see our new paper with social policy adv',
#  'rt see our new paper with social policy adv']

# %%
# importing all necessary modules

# Note that wordcloud package also provides a stop word list
# We won't be using it here - but please do explore!!!
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

comment_words = ''

# iterate through list
for tweet_text in results:
    # split the text into tokens
    tokens = tweet_text.split()
    # Append tokens to string comment_words
    comment_words += " ".join(tokens)+" "
    
# Let's make a word cloud
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                #stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
